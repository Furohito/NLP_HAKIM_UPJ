# %% [markdown]
# ## Topic Modelling
# This notebook contains a demo of LDA and LSA using the gensim library. The dataset's link can be found in the `BookSummaries_Link.md` file under the Data folder in Ch7.

# %%
# Import OS 
import os
# For NLTK virtual environments are high recommended and it requires python verisions higher than 3.5
# !pip install gensim
# !pip install nltk
# Out:
# Requirement already satisfied: gensim in c:\users\rende\miniconda3\lib\site-packages (4.3.3)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\rende\miniconda3\lib\site-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in c:\users\rende\miniconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/15.8 MB 9.3 MB/s eta 0:00:02
#    --------- ------------------------------ 3.7/15.8 MB 9.5 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.8 MB 9.7 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.8 MB 9.9 MB/s eta 0:00:01
#    ------------------------- -------------- 10.2/15.8 MB 9.8 MB/s eta 0:00:01
#    -------------------------------- ------- 12.8/15.8 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 9.9 MB/s  0:00:01
# Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    - -------------------------------------- 2.1/46.2 MB 11.8 MB/s eta 0:00:04
#    --- ------------------------------------ 4.5/46.2 MB 10.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.6/46.2 MB 10.9 MB/s eta 0:00:04
#    ------- -------------------------------- 9.2/46.2 MB 11.0 MB/s eta 0:00:04
#    --------- ------------------------------ 11.3/46.2 MB 10.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.6/46.2 MB 10.8 MB/s eta 0:00:04
#    ------------- -------------------------- 16.0/46.2 MB 10.7 MB/s eta 0:00:03
#    --------------- ------------------------ 18.1/46.2 MB 10.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 20.2/46.2 MB 10.6 MB/s eta 0:00:03
#    ------------------- -------------------- 22.5/46.2 MB 10.6 MB/s eta 0:00:03
#    --------------------- ------------------ 24.6/46.2 MB 10.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 27.0/46.2 MB 10.6 MB/s eta 0:00:02
#    ------------------------- -------------- 29.1/46.2 MB 10.5 MB/s eta 0:00:02
#    --------------------------- ------------ 31.5/46.2 MB 10.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.8/46.2 MB 10.6 MB/s eta 0:00:02
#    ------------------------------- -------- 36.2/46.2 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 38.3/46.2 MB 10.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.6/46.2 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- -- 43.0/46.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  45.4/46.2 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 10.4 MB/s  0:00:04
# Installing collected packages: numpy, scipy
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.3.3
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#     Uninstalling numpy-2.3.3:
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#       Successfully uninstalled numpy-2.3.3
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#   Attempting uninstall: scipy
#    ---------------------------------------- 0/2 [numpy]
#     Found existing installation: scipy 1.16.2
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#     Uninstalling scipy-1.16.2:
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#       Successfully uninstalled scipy-1.16.2
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    ---------------------------------------- 2/2 [scipy]
#
# Successfully installed numpy-1.26.4 scipy-1.13.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\rende\miniconda3\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\rende\AppData\Local\Temp\pip-uninstall-pcm452er'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Requirement already satisfied: nltk in c:\users\rende\miniconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\rende\miniconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\rende\miniconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\rende\miniconda3\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\rende\miniconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\rende\miniconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')

from gensim.models import LdaModel
from gensim.corpora import Dictionary
from pprint import pprint
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rende\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#tokenize, remove stopwords, non-alphabetic words, lowercase
def preprocess(textstring):
   stops =  set(stopwords.words('english'))
   tokens = word_tokenize(textstring)
   return [token.lower() for token in tokens if token.isalpha() and token not in stops]

# This is a sample path of your downloaded data set. This is currently set to a windows based path . 
# Please update it to your actual download path regradless of your choice of operating system 

data_path = "data/booksummaries.txt"  # Update this path to your actual data file location

summaries = []
for line in open(data_path, encoding="utf-8"):
   temp = line.split("\t")
   summaries.append(preprocess(temp[6]))

# Create a dictionary representation of the documents.

dictionary = Dictionary(summaries)

# Filter infrequent or too frequent words.

dictionary.filter_extremes(no_below=10, no_above=0.5)
corpus = [dictionary.doc2bow(summary) for summary in summaries]

# Make a index to word dictionary.

temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

#Train the topic model

model = LdaModel(corpus=corpus, id2word=id2word,iterations=400, num_topics=10)
top_topics = list(model.top_topics(corpus))
pprint(top_topics)
# Out:
# [([(0.0084388405, 'she'),
#    (0.006371494, 'house'),
#    (0.0060028043, 'mother'),
#    (0.0058152825, 'tells'),
#    (0.0058016437, 'back'),
#    (0.0055676913, 'he'),
#    (0.0051143584, 'finds'),
#    (0.005094575, 'one'),
#    (0.0047196657, 'home'),
#    (0.004359147, 'go'),
#    (0.0039552455, 'get'),
#    (0.003909034, 'find'),
#    (0.0037846577, 'when'),
#    (0.003452536, 'they'),
#    (0.003353687, 'father'),
#    (0.0033354876, 'day'),
#    (0.0032414442, 'after'),
#    (0.0031929524, 'man'),
#    (0.003186418, 'goes'),
#    (0.0031454326, 'new')],
#   -0.8450771218017469),
#  ([(0.009129272, 'he'),
#    (0.005415496, 'one'),
#    (0.0045062485, 'she'),
#    (0.0041417475, 'tells'),
#    (0.0040089106, 'back'),
#    (0.0036825263, 'later'),
#    (0.0036230183, 'two'),
#    (0.0035299317, 'after'),
#    (0.0035061066, 'man'),
#    (0.003400891, 'they'),
#    (0.0033646268, 'day'),
#    (0.0031898057, 'time'),
#    (0.003100751, 'also'),
#    (0.0030552014, 'go'),
#    (0.0029811922, 'when'),
#    (0.0029574602, 'mother'),
#    (0.0028936176, 'get'),
#    (0.0028222823, 'night'),
#    (0.0027623354, 'goes'),
#    (0.0027513688, 'father')],
#   -0.9331237377244628),
#  ([(0.0067992117, 'he'),
#    (0.006782821, 'father'),
#    (0.0059187002, 'family'),
#    (0.004739593, 'she'),
#    (0.0044382876, 'one'),
#    (0.0041720765, 'home'),
#    (0.0041666487, 'mother'),
#    (0.0038847367, 'sam'),
#    (0.0037627607, 'house'),
#    (0.0036979723, 'max'),
#    (0.0036260355, 'new'),
#    (0.0034524233, 'find'),
#    (0.0034132106, 'back'),
#    (0.0033983572, 'old'),
#    (0.0033026559, 'time'),
#    (0.003291288, 'life'),
#    (0.0032652752, 'when'),
#    (0.003245972, 'man'),
#    (0.0031654458, 'tells'),
#    (0.0031586278, 'two')],
#   -1.1242989042771858),
#  ([(0.007789151, 'life'),
#    (0.005831468, 'one'),
#    (0.0057869907, 'novel'),
#    (0.005668922, 'book'),
#    (0.0054621375, 'he'),
#    (0.0053437506, 'story'),
#    (0.0052174656, 'family'),
#    (0.004900307, 'school'),
#    (0.0042449497, 'time'),
#    (0.0042205323, 'also'),
#    (0.0041813785, 'she'),
#    (0.004082338, 'first'),
#    (0.0039528166, 'new'),
#    (0.0036710661, 'mother'),
#    (0.0035705063, 'in'),
#    (0.0034070446, 'father'),
#    (0.0032984037, 'love'),
#    (0.0032657692, 'two'),
#    (0.002857816, 'i'),
#    (0.0028189637, 'relationship')],
#   -1.1537798009803766),
#  ([(0.006476083, 'one'),
#    (0.004707653, 'they'),
#    (0.004446104, 'he'),
#    (0.004168728, 'find'),
#    (0.004099987, 'back'),
#    (0.0040520793, 'world'),
#    (0.0039365105, 'time'),
#    (0.0036700736, 'group'),
#    (0.0034988718, 'kill'),
#    (0.003427694, 'however'),
#    (0.0033887736, 'ship'),
#    (0.0033649856, 'new'),
#    (0.0031801206, 'two'),
#    (0.0031589419, 'city'),
#    (0.003156173, 'also'),
#    (0.0031149718, 'help'),
#    (0.0029875622, 'power'),
#    (0.0028231146, 'in'),
#    (0.0028164987, 'earth'),
#    (0.0028084018, 'human')],
#   -1.227812443155351),
#  ([(0.007958221, 'king'),
#    (0.0057146307, 'he'),
#    (0.0057003675, 'father'),
#    (0.0050167213, 'love'),
#    (0.004950376, 'she'),
#    (0.0040849885, 'two'),
#    (0.0039794846, 'one'),
#    (0.0038537674, 'son'),
#    (0.0035898539, 'young'),
#    (0.0035484617, 'brother'),
#    (0.0032616302, 'prince'),
#    (0.0032515735, 'in'),
#    (0.0031992705, 'also'),
#    (0.003152581, 'daughter'),
#    (0.0031339144, 'however'),
#    (0.0030151035, 'death'),
#    (0.0028649608, 'family'),
#    (0.0026947323, 'marry'),
#    (0.0026823112, 'mother'),
#    (0.002636911, 'queen')],
#   -1.3056828386967925),
#  ([(0.009068198, 'book'),
#    (0.0060100625, 'world'),
#    (0.005486121, 'in'),
#    (0.0051112827, 'novel'),
#    (0.0046846843, 'one'),
#    (0.0044275397, 'also'),
#    (0.0039524953, 'new'),
#    (0.0038275074, 'people'),
#    (0.003679954, 'story'),
#    (0.0034858712, 'human'),
#    (0.0034604033, 'first'),
#    (0.0032883154, 'it'),
#    (0.003280308, 'he'),
#    (0.0030948257, 'life'),
#    (0.0030112022, 'earth'),
#    (0.0029840406, 'time'),
#    (0.0029505342, 'two'),
#    (0.0029100112, 'this'),
#    (0.0028933366, 'chapter'),
#    (0.0025502203, 'history')],
#   -1.3061087657438695),
#  ([(0.013423307, 'jacky'),
#    (0.0074029323, 'they'),
#    (0.0068294425, 'find'),
#    (0.005823975, 'he'),
#    (0.0056215296, 'will'),
#    (0.0052908934, 'back'),
#    (0.004447375, 'she'),
#    (0.003907837, 'one'),
#    (0.003667737, 'tells'),
#    (0.0034077025, 'help'),
#    (0.0031550627, 'king'),
#    (0.0031275162, 'also'),
#    (0.002950959, 'in'),
#    (0.0029481577, 'story'),
#    (0.0028859584, 'go'),
#    (0.002847764, 'after'),
#    (0.0028161104, 'way'),
#    (0.002775639, 'when'),
#    (0.0026885553, 'get'),
#    (0.002559904, 'cassie')],
#   -1.531595549935664),
#  ([(0.01225825, 'ship'),
#    (0.006003281, 'captain'),
#    (0.0055148792, 'crew'),
#    (0.0045173205, 'he'),
#    (0.0044310093, 'jack'),
#    (0.0039718486, 'one'),
#    (0.0034342024, 'daniel'),
#    (0.0033920165, 'first'),
#    (0.0031505837, 'ana'),
#    (0.0030486104, 'back'),
#    (0.0029814465, 'time'),
#    (0.0027773464, 'story'),
#    (0.0027325777, 'also'),
#    (0.0027251525, 'after'),
#    (0.0026948652, 'army'),
#    (0.0026406443, 'they'),
#    (0.0026282687, 'in'),
#    (0.002619874, 'book'),
#    (0.0025656451, 'emperor'),
#    (0.0025553133, 'sea')],
#   -1.8655142736094534),
#  ([(0.006330028, 'war'),
#    (0.0049363757, 'he'),
#    (0.004661833, 'new'),
#    (0.003761836, 'one'),
#    (0.0036658125, 'also'),
#    (0.0033268128, 'in'),
#    (0.0026863343, 'two'),
#    (0.002642548, 'time'),
#    (0.0025530204, 'story'),
#    (0.002494335, 'states'),
#    (0.0024721404, 'after'),
#    (0.002451754, 'united'),
#    (0.0023935193, 'first'),
#    (0.0023916846, 'novel'),
#    (0.0023786996, 'president'),
#    (0.002182569, 'government'),
#    (0.0020396553, 'american'),
#    (0.00202067, 'dahlia'),
#    (0.0019820097, 'military'),
#    (0.0019681486, 'police')],
#   -2.222775318836058)]

# %%
for idx in range(10):
    print("Topic #%s:" % idx, model.print_topic(idx, 10))
print("=" * 20)
# Out:
# Topic #0: 0.013*"jacky" + 0.007*"they" + 0.007*"find" + 0.006*"he" + 0.006*"will" + 0.005*"back" + 0.004*"she" + 0.004*"one" + 0.004*"tells" + 0.003*"help"
# Topic #1: 0.008*"she" + 0.006*"house" + 0.006*"mother" + 0.006*"tells" + 0.006*"back" + 0.006*"he" + 0.005*"finds" + 0.005*"one" + 0.005*"home" + 0.004*"go"
# Topic #2: 0.008*"king" + 0.006*"he" + 0.006*"father" + 0.005*"love" + 0.005*"she" + 0.004*"two" + 0.004*"one" + 0.004*"son" + 0.004*"young" + 0.004*"brother"
# Topic #3: 0.007*"he" + 0.007*"father" + 0.006*"family" + 0.005*"she" + 0.004*"one" + 0.004*"home" + 0.004*"mother" + 0.004*"sam" + 0.004*"house" + 0.004*"max"
# Topic #4: 0.006*"one" + 0.005*"they" + 0.004*"he" + 0.004*"find" + 0.004*"back" + 0.004*"world" + 0.004*"time" + 0.004*"group" + 0.003*"kill" + 0.003*"however"
# Topic #5: 0.008*"life" + 0.006*"one" + 0.006*"novel" + 0.006*"book" + 0.005*"he" + 0.005*"story" + 0.005*"family" + 0.005*"school" + 0.004*"time" + 0.004*"also"
# Topic #6: 0.009*"book" + 0.006*"world" + 0.005*"in" + 0.005*"novel" + 0.005*"one" + 0.004*"also" + 0.004*"new" + 0.004*"people" + 0.004*"story" + 0.003*"human"
# Topic #7: 0.009*"he" + 0.005*"one" + 0.005*"she" + 0.004*"tells" + 0.004*"back" + 0.004*"later" + 0.004*"two" + 0.004*"after" + 0.004*"man" + 0.003*"they"
# Topic #8: 0.012*"ship" + 0.006*"captain" + 0.006*"crew" + 0.005*"he" + 0.004*"jack" + 0.004*"one" + 0.003*"daniel" + 0.003*"first" + 0.003*"ana" + 0.003*"back"
# Topic #9: 0.006*"war" + 0.005*"he" + 0.005*"new" + 0.004*"one" + 0.004*"also" + 0.003*"in" + 0.003*"two" + 0.003*"time" + 0.003*"story" + 0.002*"states"
# ====================

# %%
from gensim.models import LsiModel
lsamodel = LsiModel(corpus, num_topics=10, id2word = id2word)  # train model

pprint(lsamodel.print_topics(num_topics=10, num_words=10))
# Out:
# [(0,
#   '0.305*"he" + 0.215*"one" + 0.150*"she" + 0.140*"time" + 0.132*"back" + '
#   '0.131*"also" + 0.127*"two" + 0.125*"they" + 0.123*"tells" + 0.118*"in"'),
#  (1,
#   '0.493*"tom" + 0.226*"sophia" + 0.182*"mrs" + 0.178*"house" + 0.161*"she" + '
#   '0.154*"father" + 0.147*"mr" + 0.146*"he" + 0.138*"tells" + -0.126*"one"'),
#  (2,
#   '0.558*"tom" + 0.252*"sophia" + -0.212*"she" + -0.190*"he" + 0.184*"mrs" + '
#   '-0.164*"tells" + -0.144*"mother" + 0.136*"mr" + 0.129*"western" + '
#   '0.103*"however"'),
#  (3,
#   '-0.233*"they" + -0.204*"ship" + 0.187*"he" + -0.183*"david" + -0.180*"back" '
#   '+ -0.166*"tells" + 0.159*"family" + 0.158*"life" + -0.155*"find" + '
#   '0.153*"narrator"'),
#  (4,
#   '-0.663*"he" + 0.257*"mother" + 0.213*"she" + 0.195*"father" + '
#   '0.180*"family" + -0.122*"narrator" + -0.120*"monk" + 0.099*"school" + '
#   '0.098*"novel" + 0.093*"children"'),
#  (5,
#   '-0.485*"david" + 0.242*"king" + -0.170*"rosa" + -0.163*"book" + '
#   '-0.126*"harlan" + 0.120*"he" + -0.110*"she" + -0.108*"gould" + '
#   '0.108*"anita" + -0.107*"would"'),
#  (6,
#   '0.696*"anita" + 0.472*"richard" + -0.158*"ship" + -0.127*"jacky" + '
#   '0.085*"power" + 0.084*"edward" + 0.083*"monk" + -0.074*"mother" + '
#   '0.071*"kill" + 0.068*"scene"'),
#  (7,
#   '-0.396*"david" + -0.359*"king" + 0.224*"jacky" + 0.193*"ship" + '
#   '0.142*"monk" + 0.135*"doctor" + -0.132*"rosa" + -0.124*"arthur" + '
#   '-0.119*"prince" + -0.110*"book"'),
#  (8,
#   '0.288*"harry" + -0.280*"she" + 0.266*"narrator" + 0.225*"david" + '
#   '-0.223*"jacky" + 0.198*"monk" + 0.144*"natalie" + -0.125*"ship" + '
#   '-0.123*"says" + -0.122*"king"'),
#  (9,
#   '0.462*"harry" + -0.410*"narrator" + 0.259*"monk" + -0.220*"david" + '
#   '-0.216*"anita" + 0.180*"natalie" + -0.166*"ship" + -0.159*"he" + '
#   '-0.155*"richard" + 0.152*"dresden"')]

# %%
for idx in range(10):
    print("Topic #%s:" % idx, lsamodel.print_topic(idx, 10))
 
print("=" * 20)
# Out:
# Topic #0: 0.305*"he" + 0.215*"one" + 0.150*"she" + 0.140*"time" + 0.132*"back" + 0.131*"also" + 0.127*"two" + 0.125*"they" + 0.123*"tells" + 0.118*"in"
# Topic #1: 0.493*"tom" + 0.226*"sophia" + 0.182*"mrs" + 0.178*"house" + 0.161*"she" + 0.154*"father" + 0.147*"mr" + 0.146*"he" + 0.138*"tells" + -0.126*"one"
# Topic #2: 0.558*"tom" + 0.252*"sophia" + -0.212*"she" + -0.190*"he" + 0.184*"mrs" + -0.164*"tells" + -0.144*"mother" + 0.136*"mr" + 0.129*"western" + 0.103*"however"
# Topic #3: -0.233*"they" + -0.204*"ship" + 0.187*"he" + -0.183*"david" + -0.180*"back" + -0.166*"tells" + 0.159*"family" + 0.158*"life" + -0.155*"find" + 0.153*"narrator"
# Topic #4: -0.663*"he" + 0.257*"mother" + 0.213*"she" + 0.195*"father" + 0.180*"family" + -0.122*"narrator" + -0.120*"monk" + 0.099*"school" + 0.098*"novel" + 0.093*"children"
# Topic #5: -0.485*"david" + 0.242*"king" + -0.170*"rosa" + -0.163*"book" + -0.126*"harlan" + 0.120*"he" + -0.110*"she" + -0.108*"gould" + 0.108*"anita" + -0.107*"would"
# Topic #6: 0.696*"anita" + 0.472*"richard" + -0.158*"ship" + -0.127*"jacky" + 0.085*"power" + 0.084*"edward" + 0.083*"monk" + -0.074*"mother" + 0.071*"kill" + 0.068*"scene"
# Topic #7: -0.396*"david" + -0.359*"king" + 0.224*"jacky" + 0.193*"ship" + 0.142*"monk" + 0.135*"doctor" + -0.132*"rosa" + -0.124*"arthur" + -0.119*"prince" + -0.110*"book"
# Topic #8: 0.288*"harry" + -0.280*"she" + 0.266*"narrator" + 0.225*"david" + -0.223*"jacky" + 0.198*"monk" + 0.144*"natalie" + -0.125*"ship" + -0.123*"says" + -0.122*"king"
# Topic #9: 0.462*"harry" + -0.410*"narrator" + 0.259*"monk" + -0.220*"david" + -0.216*"anita" + 0.180*"natalie" + -0.166*"ship" + -0.159*"he" + -0.155*"richard" + 0.152*"dresden"
# ====================
