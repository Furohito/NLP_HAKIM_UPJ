# %% [markdown]
# This notebook shows how to use Elastic Search to index and search through data. We will use a dataset called CMU Book summaries [dataset](http://www.cs.cmu.edu/~dbamman/booksummaries.html). Alternateively, the dataset's link can be found in the `BookSummaries_Link.md` file under the Data folder in Ch7.
#
# For this code to work, elastic search instance has to be running in the background.
# For this you need to follow these steps :
#
# Linux :
#
#    1. Go to the elasticsearch-X.Y.Z/bin folder on your machine
#    2. Run ./elasticsearch.
#
# Windows :
#
#    1.  Download the latest [release](https://www.elastic.co/guide/en/elasticsearch/reference/current/windows.html)
#    2.  Run .\bin\elasticsearch.bat
#
# [ElasticSearch Documentation](https://www.elastic.co/guide/index.html)
#
# You should now be able to access this instance on localhost:9200

# %%
from elasticsearch import Elasticsearch 
from datetime import datetime

# %%
from elasticsearch import Elasticsearch

# Ganti 'your_password' dengan kata sandi pengguna 'elastic' Anda.
# Ganti 'path/to/your/http_ca.crt' dengan path absolut ke file sertifikat Anda.
es = Elasticsearch(
    "https://localhost:9200",
    basic_auth=("elastic", "8*zq2Ye5ufrhZ+FOf222"),
    ca_certs="E:\\elasticsearch-9.1.5\\config\\certs\\http_ca.crt"
)

# Sisa kode Anda tetap sama dan akan berfungsi setelah koneksi berhasil.
if es.indices.exists(index="myindex"):
    es.indices.delete(index='myindex', ignore=[400, 404])

# %%
#Build an index from booksummaries dataset. I am using only 500 documents for now.
path = "Data\\booksummaries.txt" #Add your path.
count = 1
for line in open(path):
    fields = line.split("\t")
    doc = {'id' : fields[0],
            'title': fields[2],
            'author': fields[3],
            'summary': fields[6]
          }

    res = es.index(index="myindex", id=fields[0], body=doc)
    count = count+1
    if count%100 == 0:
        print("indexed 100 documents")
    if count == 501:
        break
# Out:
# indexed 100 documents
# indexed 100 documents
# indexed 100 documents
# indexed 100 documents
# indexed 100 documents

# %%
#Check to see how big is the index
res = es.search(index="myindex", body={"query": {"match_all": {}}})
print("Your index has %d entries" % res['hits']['total']['value'])
# Out:
# Your index has 500 entries

# %%
#Try a test query. The query searches "summary" field which contains the text
#and does a full text query on that field.
res = es.search(index="myindex", body={"query": {"match": {"summary": "animal"}}})
print("Your search returned %d results." % res['hits']['total']['value'])
# Out:
# Your search returned 16 results.

# %%
#Printing the title field and summary field's first 100 characters for 2nd result
print(res["hits"]["hits"][2]["_source"]["title"])
print(res["hits"]["hits"][2]["_source"]["summary"][:100])
# Out:
# Dead Air
#  The first person narrative begins on 11 September 2001, and Banks uses the protagonist's conversati

# %%
#match query considers both exact matches, and fuzzy matches and works as a OR query. 
#match_phrase looks for exact matches.
while True:
    query = input("Enter your search query: ")
    if query == "STOP":
        break
    res = es.search(index="myindex", body={"query": {"match_phrase": {"summary": query}}})
    print("Your search returned %d results:" % res['hits']['total']['value'])
    for hit in res["hits"]["hits"]:
        print(hit["_source"]["title"])
        #to get a snippet 100 characters before and after the match
        loc = hit["_source"]["summary"].lower().index(query)
        print(hit["_source"]["summary"][:100])
        print(hit["_source"]["summary"][loc-100:loc+100])
# Out:
# Your search returned 55 results:
# King John
#  King John receives an ambassador from France, who demands, on pain of war, that he renounce his thr
#  John knights the Bastard under the name Richard. In France, King Philip and his forces besiege the English-ruled town of Angiers, threatening attack unless its citizens support Arthur. Philip is supp
# The English Patient
#  The historical backdrop for this novel is the Second World War in Northern Africa and Italy. Hana,
# illa San Girolamo in Italy, which is filled with hidden, undetonated bombs. All she knows about her English patient is that he was burned beyond recognition in a plane crash before being taken to the
# Henry V
#  Elizabethan stages did not use scenery. Acknowledging the difficulty of conveying great battles and
# one stomach with our play", a humorous reference to the fact that the scene of the play crosses the English Channel. The Chorus appears again, seeking support for the English navy: "Grapple your minds
# Vurt
#  Vurt tells the story of Scribble and his "gang", the Stash Riders, as they search for his missing s
# real". Before the novel begins, Scribble and his sister-lover take a shared trip into a vurt called English Voodoo, but upon awakening Scribble finds his sister has been replaced by an amorphous blob
# England, England
#  England, England is divided into three parts entitled "England", "England, England" and "Anglia". T
# on the protagonist Martha Cochrane and her childhood memories. Growing up in the surrounding of the English countryside, her peaceful childhood gets disrupted when her father leaves the family. Martha
# Death of a Hero
#  Death of a Hero is the story of a young English artist named George Winterbourne who enlists in the
#
# The Red House Mystery
#  The setting is an English country house, where Mark Ablett has been entertaining a house party cons
#
# Good Omens
#  It is the coming of the End Times: the Apocalypse is near, and Final Judgment will soon descend upo
# pite being the harbinger of the Apocalypse, has lived a perfectly normal life as the son of typical English parents and as a result has no idea of his true powers. As Adam blissfully and naively uses
# The Scarlet Pimpernel
#  The Scarlet Pimpernel is set in 1792, during the early stages of the French Revolution. Marguerite
# s of the French Revolution. Marguerite St. Just, a beautiful French actress, is the wife of wealthy English fop Sir Percy Blakeney, a baronet. Before their marriage, Marguerite took revenge upon the M
# The Prisoner of Zenda
#  On the eve of the coronation of King Rudolf of Ruritania, his brother, Prince Michael, has him drug
# d Fritz von Tarlenheim, attendants of the King, persuade his identical cousin Rudolf Rassendyll, an English visitor, to impersonate the King at the coronation. The unconscious king is abducted and imp
# Your search returned 0 results:
# Your search returned 5 results:
# Robinson Crusoe
#  Crusoe (the family name corrupted from the German name "Kreutznaer") sets sail from the Queen's Doc
#  is enslaved by a Moor. Two years later, he escapes in a boat with a boy named Xury; a Captain of a Portuguese ship off the west coast of Africa rescues him. The ship is en route to Brazil. With the c
# The Further Adventures of Robinson Crusoe
#  The book starts with the statement about Crusoe's marriage in England. He bought a little farm in B
# y visited Nanking near the river of Kilam, and sailed southwards to a port called Quinchang. An old Portuguese pilot suggested them to go to Ningpo by the mouth of a river. This Ningpo was a canal tha
# Candide, ou l'Optimisme
#  Candide contains thirty episodic chapters, which may be grouped into two main schemes: one consists
# uation by Pangloss. The next day, Pangloss discusses his optimistic philosophy with a member of the Portuguese Inquisition, and he and Candide are arrested for heresy, set to be tortured and killed in
# King Solomon's Mines
#  Allan Quatermain, an adventurer and white hunter based in Durban, in what is now South Africa, is a
# a cave where they find the frozen corpse of José Silvestre (also spelt Silvestra), the 16th-century Portuguese explorer who drew the map in his own blood. That night, a second servant dies from the co
# Gulliver's Travels
#  ;4 May 1699 — 13 April 1702 The book begins with a short preamble in which Lemuel Gulliver, in the
# ason, is a danger to their civilization, and expels him. He is then rescued, against his will, by a Portuguese ship, and is surprised to see that Captain Pedro de Mendez, a Yahoo, is a wise, courteous
# Your search returned 0 results:
# Your search returned 0 results:
# Your search returned 0 results:
# Your search returned 0 results:
# Your search returned 0 results:
# Your search returned 0 results:
# Your search returned 2 results:
# The Stranger
#  Part One begins with Meursault finding out of his mother's death. At her funeral, he expresses none
# unfaithful, and Raymond is let off with a warning. After this, the girlfriend's brother and several Arab friends begin tailing Raymond. Raymond invites Meursault and Marie to a friend's beach house fo
# Adventures of Huckleberry Finn
#  The story begins in fictional St. Petersburg, Missouri, on the shore of the Mississippi River, some
# ake bills for an escaped slave; and later they paint him up entirely in blue and call him the "Sick Arab". On one occasion they arrive in a town and advertise a three-night engagement of a play which
# Your search returned 2 results:
# Goldfinger
#  Fleming structured the novel in three sections—"Happenstance", "Coincidence" and" Enemy action"—whi
# scapes being caught on camera looking over the house. Goldfinger introduces Bond to his factotum, a Korean named Oddjob. Issued by MI6 with an Aston Martin DB Mark III, Bond trails Goldfinger as he ta
# Alas, Babylon
#  Randy (Randolph) Bragg, the protagonist, is a man who dabbles at law and lives a life with little p
# nent Central Florida political family, Bragg is a former active duty U.S. Army infantry officer and Korean War veteran whose own foray into public life was a run for the Florida State Legislature whic
# Your search returned 6 results:
# Debt of Honor
#  In New York City, Japanese industrialist Raizo Yamata purchases a controlling interest in an Americ
#
# The Man in the High Castle
#  Giuseppe Zangara's assassination of U.S. President-elect Franklin D. Roosevelt, in 1933, led to the
# lavic peoples; the few whom they allowed to live were confined to reservations. In the Pacific, the Japanese destroyed the entire U.S. Navy fleet in a decisive, definitive attack on Pearl Harbor; ther
# Cryptonomicon
#  The action takes place in two periods: the Second World War and the late 1990s, during the Internet
# n of China and Guadalcanal, serves in unit 2702, carrying out Waterhouse's plans. At the same time, Japanese soldiers including mining engineer Goto Dengo, an old friend of Shaftoe's, are assigned to
# Pacific Overtures
#  ;Act I Conceived as a sort of Japanese playwright's version of an American musical about American i
#
# No Logo
#  The book comprises four sections: "No Space", "No Choice", "No Jobs", and "No Logo". The first thre
# onomic crash in the 1980s (Latin American debt crisis, Black Monday (1987), Savings and loan crisis Japanese asset price bubble), corporations began to seriously rethink their approach to marketing, a
# The Tale of Genji
#  The work recounts the life of a son of the Japanese emperor, known to readers as Hikaru Genji, or "
#
# Your search returned 0 results:
# Your search returned 0 results:
# Your search returned 14 results:
# East Wind: West Wind
#  Kwei-lan is put into an arranged marriage, but her husband is not what she expects. They do not liv
# her husband is not what she expects. They do not live in her parents' courts (which was expected in China then). He is a medical doctor and does not seem to take interest in her until after she asks h
# Shadow Puppets
#  Peter, Ender's brother, is now Hegemon of Earth. Accepting a tip from inside China, where Achilles
#
# The Further Adventures of Robinson Crusoe
#  The book starts with the statement about Crusoe's marriage in England. He bought a little farm in B
#  a ship that later turned out to be stolen. Therefore they went to the river of Cambodia and Cochin-China or the bay of Tonquin, until they came to the latitude of 22 degrees and 30 minutes, and ancho
# Around the World in Eighty Days
#  The story starts in London on October 1, 1872. Phileas Fogg is a rich English gentleman and bachelo
# ean || 13 days |----- | Bombay to Calcutta, India || rail || 3 days |----- | Calcutta to Hong Kong, China || steamer across South China Sea || 13 days |----- | Hong Kong to Yokohama, Japan || steamer
# Cryptonomicon
#  The action takes place in two periods: the Second World War and the late 1990s, during the Internet
# ive explanations for the Allied intelligence successes. Marine sergeant Bobby Shaftoe, a veteran of China and Guadalcanal, serves in unit 2702, carrying out Waterhouse's plans. At the same time, Japan
# On Golden Pond
#  May Norman and Ethel arrive at the summer house, finding it in need of repairs. There are hints tha
# ornia. Norman seems to suffer a heart attack, (whilst picking up a box of his mother-in-law's heavy china) but recovers, and the pair leave their home along Golden Pond.
#
# Guns, Germs, and Steel
#  The prologue opens with an account of Diamond's conversation with Yali, a New Guinean politician. T
# offers a very brief explanation of why western European societies, rather than other powers such as China, have been the dominant colonizers. * Other advanced cultures developed in areas whose geograp
# Fast Food Nation: The Dark Side of the All-American Meal
#  Schlosser opens the book with the ironic delivery of a pizza to the top secret military base, Cheye
#  of the book discusses the fast food industry's role in globalization, linking increased obesity in China and Japan with the arrival of fast food. The book also includes a summary of the McLibel Case.
# Romance of the Three Kingdoms
#  One of the greatest achievements of Romance of the Three Kingdoms is the extreme complexity of its
# Without a strong central government, warlords begin to rise and fight each other for land, plunging China into a state of anarchy. In the north, Yuan Shao and Gongsun Zan are at war, and in the south,
# Lost Horizon
#  The origin of the eleven numbered chapters of the novel is explained in a prologue and epilogue, wh
# sappearance, he discovered Conway in a French mission hospital in Chung-Kiang (probably Chongqing), China, suffering from amnesia. Conway recovered his memory and told Rutherford his story, then slipp
# Your search returned 1 results:
# To Kill a Mockingbird
#  The book opens with the Finch family's ancestor, Simon Finch, a Cornish Methodist fleeing religious
# ticus agrees to defend Tom. Other children taunt Jem and Scout for Atticus' actions, calling him a "nigger-lover". Scout is tempted to stand up for her father's honor by fighting even though he has to
# Your search returned 1 results:
# To Kill a Mockingbird
#  The book opens with the Finch family's ancestor, Simon Finch, a Cornish Methodist fleeing religious
# ticus agrees to defend Tom. Other children taunt Jem and Scout for Atticus' actions, calling him a "nigger-lover". Scout is tempted to stand up for her father's honor by fighting even though he has to
# Your search returned 65 results:
# The Gunslinger
#  It tells the story of the gunslinger, Roland of Gilead, and his quest to catch the man in black, th
#
# Murder on the Orient Express
#  Hercule Poirot boards the Orient Express in Constantinople. The train is unusually crowded for the
# FFF" style="text-align: center; font-size: 80%" |-bgcolor="#F5F5DC" |style="border-right: 1px solid black; background:#C0C0C0"| &nbsp; || style="background:#98FB98" width="50"| &nbsp; || colspan="12"
# Treasure Island
#  The novel is divided into 6 parts and 34 chapters: Jim Hawkins is the narrator of all except for ch
# for chapters 16-18, which are narrated by Doctor Livesey. The novel opens in the seaside village of Black Hill Cove in south-west England (to Stevenson, in his letters and in the related fictional pla
# The Masque of the Red Death
#  The story takes place at the castellated abbey of the "happy and dauntless and sagacious" Prince Pr
#  in a specific color: Blue, purple, green, orange, white, and violet. The last room is decorated in black and is illuminated by a scarlet light- "a deep blood color": because of this chilling pair of
# The Human Stain
#  The story is told by Nathan Zuckerman, a writer who lives quietly in New England, where Coleman Sil
# nal institution in the Berkshires of western Massachusetts. At 71, Silk is accused of racism by two black students because of referring to them as "spooks". As they have never shown up in his seminar,
# Chocolat
#  The story begins as two strangers, Vianne Rocher, and her small daughter Anouk, move into the small
# nd of "domestic magic" to earn their living. Throughout her life, Vianne has been running from the "Black Man", a recurring motif in her mother's folklore. When her mother is killed by a cab, Vianne c
#  revolution, when she finds she has lost all autonomy to her husband, through her failed attempt to escape with her husband and daughter to Canada, to her indoctrination into life as a handmaid. Throu
# The Eyes of the Dragon
#  The Eyes of the Dragon takes place entirely within the realm of Delain (which itself is located wit
# Peyna is puzzled by the requests, but, seeing no harm in them, grants them. Five years later, Peter escapes from the Needle, having used the toy loom in the dollhouse and threads from the napkins to m
# Heretics of Dune
#  Much has changed in the millennium and a half since the death of the God Emperor. Sandworms have re
# e operation, however, Teg and his companions are ambushed. Teg is captured while Lucilla and Duncan escape. Teg is tortured by a T-Probe, but under pressure discovers a new ability: he is able to spee
# Time out of Joint
#  As the novel opens, its protagonist Ragle Gumm believes that he lives in the year 1959 in a quiet A
# the deception surrounding him (erected to protect and exploit him) begins to unravel. Gumm tries to escape the town and is turned back by kafkaesque obstructions. He sees a magazine with himself on th
# Your search returned 0 results:
# Your search returned 41 results:
# David Copperfield
#  The story traces the life of David Copperfield from childhood to maturity. David was born in Blunde
# hich David answers in the course of the novel. As David grows to adulthood, a variety of characters enter, leave, and re-enter his life. These include Peggotty – his mother's faithful former housekeep
# The Prisoner of Zenda
#  On the eve of the coronation of King Rudolf of Ruritania, his brother, Prince Michael, has him drug
#  betrothed, but cannot tell her the truth. He determines to rescue the king and leads an attempt to enter the castle of Zenda. The King is rescued and is restored to his throne, but the lovers, in dut
# Book of Numbers
#  God orders Moses, in the wilderness of Sinai, to number those able to bear arms&mdash;of all the me
# h milk and honey"; the other spies say that it is inhabited by giants, and the Israelites refuse to enter the land. Yahweh decrees that the Israelites will be punished for their loss of faith by havin
# The Great Divorce
#  The narrator inexplicably finds himself in a grim and joyless city, the "grey town", which is eithe
# an excursion to some other place (and which eventually turns out to be the foothills of heaven). He enters the bus and converses with his fellow passengers as they travel. When the bus reaches its des
# Microserfs
#  The plot of the novel has two distinct movements: the events at Microsoft and in Redmond, Washingto
# characters' lives change drastically once they leave the limited sphere of the Microsoft campus and enter the world of "One-Point-Oh". They begin to work on a project called "Oop!" (a reference to obj
# Ender's Game
#  In the far future, humanity has discovered interstellar travel and faster-than-light communication
# ed "buggers" due to their insect-like appearance. The Formics attacked the humans and the two races enter into a series of wars. Despite political conflict on Earth between three ruling parties, the H
# The End of Eternity
#  The Eternity of the title is an organization and a place which exists outside time. It is staffed b
# -seventh century. The Eternals are capable of traveling “upwhen” and “downwhen” within Eternity and entering the conventional temporal world at almost any point of their choice, apart from a section o
# Glory Road
#  Evelyn Cyril "E.C." Gordon (also known as "Easy" and "Flash") has been recently discharged from an
# ly before the final quest for the Egg itself, Oscar and Star get married. The team then proceeds to enter the tower in which the Egg has been hidden, navigating a maze of illusions and optical tricks.
# Leviticus
#  Chapters 1–5 describe the various sacrifices from the sacrificers' point of view, although the prie
# od. Leviticus 16 concerns the Day of Atonement. This is the only day on which the High Priest is to enter the holiest part of the sanctuary, the holy of holies. He is to sacrifice a bull for the sins
# Cymbeline
#  Imogen (or Innogen), daughter of the British king Cymbeline, is in love with Posthumus Leonatus, a
# ot know their origin, but are nevertheless possessed of royal passion and heartiness. The three men enter their cave and find "Fidele," and the young men are captivated by "his" beauty. Leaving "Fidel
