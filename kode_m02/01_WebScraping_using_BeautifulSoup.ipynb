# %% [markdown]
# # In this notebook we show how we can scrap data from webpages using the [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/), a python library.
# <br><br>

# %%
# To install only the requirements of this notebook, uncomment the lines below and run this cell

# ===========================

# !pip install numpy==1.19.5
# !pip install beautifulsoup4

# ===========================
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\rende\anaconda3\lib\site-packages (4.6.3)

# %%
# To install the requirements for the entire chapter, uncomment the lines below and run this cell

# ===========================

try:
    import google.colab
    # For Google Colab, install requirements from the remote file
    # Use %pip instead of !pip for compatibility
    # The following line downloads and installs each requirement
    # If running locally, this block will raise ModuleNotFoundError and skip to except
    # Note: %pip does not support piping from curl directly, so we use !curl here to download first
    # !curl -O https://raw.githubusercontent.com/practical-nlp/practical-nlp/master/Ch2/ch2-requirements.txt
    # %pip install -r ch2-requirements.txt
except ModuleNotFoundError:
    # For local environments, install from local requirements file
    # %pip install -r "ch2-requirements.txt"
# ===========================
# Out:
# Collecting numpy==1.19.5 (from -r ch2-requirements.txt (line 1))
#   Using cached numpy-1.19.5.zip (7.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ~~~~~~~~^^^^^^^^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\cli\req_command.py", line 68, in wrapper
#     return func(self, options, args)
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\commands\install.py", line 387, in run
#     requirement_set = resolver.resolve(
#         reqs, check_supported_wheels=not options.target_dir
#     )
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 96, in resolve
#     result = self._result = resolver.resolve(
#                             ~~~~~~~~~~~~~~~~^
#         collected.requirements, max_rounds=limit_how_complex_resolution_can_be
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_vendor\resolvelib\resolvers\resolution.py", line 515, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_vendor\resolvelib\resolvers\resolution.py", line 388, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_vendor\resolvelib\resolvers\resolution.py", line 141, in _add_to_criteria
#     if not criterion.candidates:
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_vendor\resolvelib\structs.py", line 194, in __bool__
#     return bool(self._sequence)
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 163, in __bool__
#     self._bool = any(self)
#                  ~~~^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 147, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#                        ^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 37, in _iter_built
#     candidate = func()
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 187, in _make_candidate_from_link
#     base: Optional[BaseCandidate] = self._make_base_candidate_from_link(
#                                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         link, template, name, version
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 233, in _make_base_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#                                        ~~~~~~~~~~~~~^
#         link,
#         ^^^^^
#     ...<3 lines>...
#         version=version,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 306, in __init__
#     super().__init__(
#     ~~~~~~~~~~~~~~~~^
#         link=link,
#         ^^^^^^^^^^
#     ...<4 lines>...
#         version=version,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 159, in __init__
#     self.dist = self._prepare()
#                 ~~~~~~~~~~~~~^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 236, in _prepare
#     dist = self._prepare_distribution()
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 317, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\operations\prepare.py", line 532, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\operations\prepare.py", line 647, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#         req,
#     ...<3 lines>...
#         self.check_build_deps,
#     )
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\operations\prepare.py", line 71, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         finder, build_isolation, check_build_deps
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\distributions\sdist.py", line 56, in prepare_distribution_metadata
#     self._install_build_reqs(finder)
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\distributions\sdist.py", line 126, in _install_build_reqs
#     build_reqs = self._get_build_requires_wheel()
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\distributions\sdist.py", line 103, in _get_build_requires_wheel
#     return backend.get_requires_for_build_wheel()
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_internal\utils\misc.py", line 684, in get_requires_for_build_wheel
#     return super().get_requires_for_build_wheel(config_settings=cs)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 196, in get_requires_for_build_wheel
#     return self._call_hook(
#            ~~~~~~~~~~~~~~~^
#         "get_requires_for_build_wheel", {"config_settings": config_settings}
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\rende\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 402, in _call_hook
#     raise BackendUnavailable(
#     ...<4 lines>...
#     )
# pip._vendor.pyproject_hooks._impl.BackendUnavailable: Cannot import 'setuptools.build_meta'

# %%
# making the necessary imports
from pprint import pprint
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
myurl = "https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" # specify the url

from urllib.request import Request

req = Request(myurl, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(req).read() # query the website so that it returns a html page  
soupified = BeautifulSoup(html, 'html.parser') # parse the html in the 'html' variable, and store it in Beautiful Soup format

# %% [markdown]
# As the size of the HTML webpage (soupified) is large, we are just showing some of its output (only 2000 characters).

# %%
pprint(soupified.prettify())      # for printing the full HTML structure of the webpage
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="html__responsive " itemscope="" '
#  'itemtype="https://schema.org/QAPage" lang="en">\n'
#  ' <head>\n'
#  '  <title>\n'
#  '   datetime - How do I get the current time in Python? - Stack Overflow\n'
#  '  </title>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" '
#  'rel="shortcut icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="apple-touch-icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="image_src"/>\n'
#  '  <link href="/opensearch.xml" rel="search" title="Stack Overflow" '
#  'type="application/opensearchdescription+xml"/>\n'
#  '  <link '
#  'href="https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python" '
#  'rel="canonical">\n'
#  '   <meta content="width=device-width, height=device-height, '
#  'initial-scale=1.0, minimum-scale=1.0" name="viewport"/>\n'
#  '   <meta content="website" property="og:type">\n'
#  '    <meta '
#  'content="https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python" '
#  'property="og:url"/>\n'
#  '    <meta content="Stack Overflow" property="og:site_name"/>\n'
#  '    <meta '
#  'content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" '
#  'itemprop="image primaryImageOfPage" property="og:image"/>\n'
#  '    <script type="application/ld+json">\n'
#  '     {\n'
#  '              "@context" : "https://schema.org",\n'
#  '              "@type" : "WebSite",\n'
#  '              "name" : "Stack Overflow",\n'
#  '              "url" : "https://stackoverflow.com"\n'
#  '            }\n'
#  '    </script>\n'
#  '    <meta content="summary" name="twitter:card"/>\n'
#  '    <meta content="stackoverflow.com" name="twitter:domain"/>\n'
#  '    <meta content="How do I get the current time in Python?" itemprop="name" '
#  'name="twitter:title" property="og:title"/>\n'
#  '    <meta content="How do I get the current time in Python?" '
#  'itemprop="description" name="twitter:description" '
#  'property="og:description"/>\n'
#  '    <script id="webpack-public-path" type="text/uri-list">\n'
#  '     https://cdn.sstatic.net/\n'
#  '    </script>\n'
#  '    <script '
#  'src="https://ajax.googleapis.com/ajax/libs/jquery/3.7.1/jquery.min.js">\n'
#  '    </script>\n'
#  '    <script defer="" '
#  'src="https://cdn.sstatic.net/Js/third-party/npm/@stackoverflow/stacks/dist/js/stacks.min.js?v=c7bcc7a1b4fd">\n'
#  '    </script>\n'
#  '    <script src="https://cdn.sstatic.net/Js/stub.en.js?v=a23cd7c588df">\n'
#  '    </script>\n'
#  '    <link href="https://cdn.sstatic.net/Shared/stacks.css?v=b2264ccf0463" '
#  'rel="stylesheet" type="text/css"/>\n'
#  '    <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/primary.css?v=1172447e1393" '
#  'rel="stylesheet" type="text/css"/>\n'
#  '    <link href="/feeds/question/415511" rel="alternate" title="Feed for '
#  'question \'How do I get the current time in Python?\'" '
#  'type="application/atom+xml"/>\n'
#  '    <script defer="" '
#  'src="https://cdn.sstatic.net/Js/misc/copy.en.js?v=de4c86ab6ebe">\n'
#  '    </script>\n'
#  '    <script data-module-name="entry-points/misc/copy.mod" '
#  'data-role="module-args" type="application/json">\n'
#  '     '
#  '{"sortType":4,"numberOfVisibleAnswers":30,"trackQuestions":true,"trackArticles":false,"userReputation":0,"userReputationBand":0,"sendPrizmEvent":false,"sendAEHEvent":true}\n'
#  '    </script>\n'
#  '    <script>\n'
#  '     StackExchange.ready(function () {\n'
#  '\n'
#  '                    StackExchange.using("snippets", function () {\n'
#  '                        StackExchange.snippets.initSnippetRenderer();\n'
#  '                    });\n'
#  '                    \n'
#  '                StackExchange.using("postValidation", function () {\n'
#  '                    '
#  "StackExchange.postValidation.initOnBlurAndSubmit($('#post-form'), 2, "
#  "'answer');\n"
#  '                });\n'
#  '\n'
#  '\n'
#  '                '
#  'StackExchange.question.init({showAnswerHelp:true,showTrendingSortLaunchPopover:false,showTrendingSortPostLaunchPopover:false,totalCommentCount:2,shownCommentCount:2,enableTables:true,questionId:415511});\n'
#  '\n'
#  '                styleCode();\n'
#  '\n'
#  "                    StackExchange.realtime.subscribeToQuestion('1', "
#  "'415511');\n"
#  '                    StackExchange.using("gps", function () { '
#  "StackExchange.gps.trackOutboundClicks('#content', '.js-post-body'); });\n"
#  '\n'
#  '\n'
#  '            });\n'
#  '    </script>\n'
#  '    <link '
#  'href="https://cdn.sstatic.net/Shared/Channels/channels.css?v=2c98e83b4da0" '
#  'rel="stylesheet" type="text/css"/>\n'
#  '    <script data-module-name="args/options.mod" data-role="module-args" '
#  'type="application/json">\n'
#  '     '
#  '{"options":{"locale":"en","serverTime":1757389674,"routeName":"Questions/Show","stackAuthUrl":"https://stackauth.com","networkMetaHostname":"meta.stackexchange.com","site":{"name":"Stack '
#  'Overflow","description":"Q\\u0026A for professional and enthusiast '
#  'programmers","isNoticesTabEnabled":true,"enableNewTagCreationWarning":true,"insertSpaceAfterNameTabCompletion":false,"id":1,"cookieDomain":".stackoverflow.com","childUrl":"https://meta.stackoverflow.com","negativeVoteScoreFloor":null,"enableSocialMediaInSharePopup":true,"protocol":"https"},"user":{"fkey":"4417dcc33c14874f9bfce957dc609794fb4ed5185ad16c86d8686c5f17054b1a","tid":"5bbffa88-6ad0-4a40-aba1-56398cb606d4","rep":0,"isAnonymous":true,"isAnonymousNetworkWide":true},"events":{"postType":{"question":1},"postEditionSection":{"title":1,"body":2,"tags":3}}}}\n'
#  '    </script>\n'
#  '    <script data-module-name="args/settings.mod" data-role="module-args" '
#  'type="application/json">\n'
#  '     '
#  '{"settings":{"intercom":{"appId":"inf0secd"},"paths":{"jQueryUICSSPath":"https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.0/themes/smoothness/jquery-ui.css","jQueryUIJSPath":"https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.0/jquery-ui.min.js"},"tags":{},"elections":{"opaVoteResultsBaseUrl":"https://www.opavote.com/results/"},"snippets":{"stacksEditorSnippetsEnabledFor":{"Metadata":{"Name":"SnippetSettings.StacksEditorSnippetsEnabledFor","Filter":0},"AppliedFilter":0,"IsNobody":false,"All":true,"Anonymous":false,"LoggedIn":false,"ChannelsMembers":false,"Moderators":false,"Employees":false,"Developers":false,"TeamAdmins":false,"AccountIds":[],"ExcludedAccountIds":[],"Serialization":"All"},"snippetsEnabled":true,"renderDomain":"stacksnippets.net"},"accounts":{"currentPasswordRequiredForChangingStackIdPassword":true},"legal":{"oneTrustTCFConfigId":"c3d9f1e3-55f3-4eba-b268-46cee4c6789c","useCustomConsent":false},"image":{"maxImageUploadSizeInBytes":10485760,"maxImageUploadSizeInBytesAnimatedGif":2097152},"auth":{"oauthInPopup":true},"site":{"allowImageUploads":true,"forceHttpsImages":true,"stacksEditorPreviewEnabled":true,"enableImageHttps":true,"enableUserHovercards":true,"styleCode":true},"questions":{"enableSavesFeature":true,"questionTitleLengthStartLiveWarningChars":50,"maxTitleSize":150,"enableQuestionTitleLengthLiveWarning":true},"mentions":{"maxNumUsersInDropdown":50},"subscriptions":{"defaultBasicMaxTrueUpSeats":250,"defaultMaxTrueUpSeats":1000,"defaultFreemiumMaxTrueUpSeats":50},"flags":{"allowRetractingCommentFlags":true,"allowRetractingFlags":true},"search":{},"userMessaging":{"showNewFeatureNotice":true},"questionLinkTitleReplacement":{"maxReplacementsPerSite":20,"maxNumberOfSitesProcessed":10},"comments":{},"markdown":{"enableTables":true}}}\n'
#  '    </script>\n'
#  '    <script>\n'
#  '     StackExchange.init();\n'
#  '    </script>\n'
#  '    <script>\n'
#  '     '
#  'StackExchange.using.setCacheBreakers({"Js/adops.en.js":"6da43f5e0a84","Js/ask.en.js":"","Js/begin-edit-event.en.js":"dd955babf04d","Js/events.en.js":"","Js/explore-qlist.en.js":"ee2a4f8c3992","Js/full-anon.en.js":"ed78b7165aaf","Js/full.en.js":"0815e7e5c7b2","Js/highlightjs-loader.en.js":"367954505ed3","Js/inline-tag-editing.en.js":"8517756a2cb6","Js/keyboard-shortcuts.en.js":"c255a5a5979b","Js/markdown-it-loader.en.js":"9e901e1e3a2c","Js/mentions-transpiled.en.js":"adcf85e61d88","Js/moderator.en.js":"a3910dc00477","Js/postCollections-transpiled.en.js":"27fabb0f4bf8","Js/post-validation.en.js":"44d59ccfc490","Js/question-editor.en.js":"","Js/review-v2-transpiled.en.js":"b98fa77fd1d3","Js/revisions.en.js":"9dd135bb585f","Js/stacks-editor.en.js":"363f5dd1317a","Js/tageditor.en.js":"5b8f289d02ef","Js/tageditornew.en.js":"da1bb9b12d0f","Js/tagsuggestions.en.js":"c54b483b692e","Js/wmd.en.js":"6c772750a204","Js/snippet-javascript-codemirror.en.js":"ede55efa5a37"});\n'
#  '        StackExchange.using("gps", function() {\n'
#  '             StackExchange.gps.init(false);\n'
#  '        });\n'
#  '    </script>\n'
#  '    <noscript id="noscript-css">\n'
#  '     <style>\n'
#  '      body,.s-topbar{margin-top:1.9em}\n'
#  '     </style>\n'
#  '    </noscript>\n'
#  '   </meta>\n'
#  '  </link>\n'
#  ' </head>\n'
#  ' <body class="question-page unified-theme">\n'
#  '  <div id="signup-modal-container">\n'
#  '  </div>\n'
#  '  <script data-module-name="islands/signup-modal/index.mod" '
#  'data-role="module-args" type="application/json">\n'
#  '   '
#  '{"ContainerElementId":"signup-modal-container","FKey":"4417dcc33c14874f9bfce957dc609794fb4ed5185ad16c86d8686c5f17054b1a","TriggerEvent":"signupModalShow","OauthInPopup":true,"ReturnUrl":"https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python","ReturnUrlForPopup":"https://stackoverflow.com/users/after-signup/oauth-only","SiteName":"Stack '
#  'Overflow","SiteLogoPath":"https://cdn.sstatic.net/Sites/stackoverflow/Img/icon-48.png?v=b7e36f88ff92","AuthProviders":["Google","GitHub"],"ParentSiteUrl":"","IsInitiallyVisible":false}\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/svelte.en.js?v=b3500af90019">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/stacks-svelte.en.js?v=1c6c229c6a50">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/8901.en.js?v=9ff34567d3a5">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="https://cdn.sstatic.net/Js/islands/signup-modal.en.js?v=6323ca6efb84">\n'
#  '  </script>\n'
#  '  <script defer="">\n'
#  '   dispatchEvent(new CustomEvent("openSignupModal"));\n'
#  '  </script>\n'
#  '  <div id="one-tap-container">\n'
#  '  </div>\n'
#  '  <script data-module-name="islands/one-tap/index.mod" '
#  'data-role="module-args" type="application/json">\n'
#  '   '
#  '{"ContainerElementId":"one-tap-container","FKey":"4417dcc33c14874f9bfce957dc609794fb4ed5185ad16c86d8686c5f17054b1a","GoogleClientId":"717762328687-iludtf96g1hinl76e4lc1b9a82g457nn.apps.googleusercontent.com","Autoselect":false,"ReturnUrl":"https%253a%252f%252fstackoverflow.com%252fquestions%252f415511%252fhow-do-i-get-the-current-time-in-python"}\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/svelte.en.js?v=b3500af90019">\n'
#  '  </script>\n'
#  '  <script defer="" '
#  'src="https://cdn.sstatic.net/Js/islands/one-tap.en.js?v=fd64ec49bac4">\n'
#  '  </script>\n'
#  '  <div id="notify-container">\n'
#  '  </div>\n'
#  '  <div id="custom-header">\n'
#  '  </div>\n'
#  '  <header class="s-topbar ps-fixed t0 l0 js-top-bar">\n'
#  '   <a class="s-topbar--skip-link" href="#content">\n'
#  '    Skip to main content\n'
#  '   </a>\n'
#  '   <div class="s-topbar--container">\n'
#  '    <a aria-controls="left-sidebar" aria-expanded="false" '
#  'aria-haspopup="true" class="s-topbar--menu-btn js-left-sidebar-toggle" '
#  'href="#">\n'
#  '     <span>\n'
#  '     </span>\n'
#  '    </a>\n'
#  '    <div class="topbar-dialog leftnav-dialog js-leftnav-dialog dno">\n'
#  '     <div class="left-sidebar js-unpinned-left-sidebar" '
#  'data-can-be="left-sidebar" data-is-here-when="sm">\n'
#  '     </div>\n'
#  '    </div>\n'
#  '    <a class="s-topbar--logo js-gps-track" '
#  'data-gps-track="top_nav.click({is_current:false, location:2, '
#  'destination:8}); homelogo_nav.click({location:2})" '
#  'href="https://stackoverflow.com">\n'
#  '     <span class="-img _glyph">\n'
#  '      Stack Overflow\n'
#  '     </span>\n'
#  '    </a>\n'
#  '    <ol class="s-navigation fw-nowrap" role="presentation">\n'
#  '     <li class="md:d-none">\n'
#  '      <a class="s-navigation--item js-gps-track" data-ga=\'["top '
#  'navigation","about menu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:7})" '
#  'href="https://stackoverflow.co/">\n'
#  '       <span class="s-navigation--item-text" data-text="About">\n'
#  '        About\n'
#  '       </span>\n'
#  '      </a>\n'
#  '     </li>\n'
#  '     <li>\n'
#  '      <button aria-controls="products-popover" aria-expanded="false" '
#  'class="s-navigation--item js-gps-track" data-action="s-popover#toggle" '
#  'data-controller="s-popover" data-ga=\'["top navigation","products menu '
#  'click",null,null,null]\' data-gps-track="top_nav.products.click({location:2, '
#  'destination:1})" data-s-popover-toggle-class="is-selected" type="button">\n'
#  '       <span class="s-navigation--item-text" data-text="Products">\n'
#  '        Products\n'
#  '       </span>\n'
#  '      </button>\n'
#  '     </li>\n'
#  '     <li class="md:d-none">\n'
#  '      <a class="s-navigation--item js-gps-track" data-ga=\'["top '
#  'navigation","learn more - teams",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:7})" '
#  'href="https://stackoverflow.co/teams/">\n'
#  '       <span class="s-navigation--item-text" data-text="For Teams">\n'
#  '        For Teams\n'
#  '       </span>\n'
#  '      </a>\n'
#  '     </li>\n'
#  '    </ol>\n'
#  '    <div aria-hidden="true" class="s-popover ws2 mtn2 p0" '
#  'id="products-popover" role="menu">\n'
#  '     <div class="s-popover--arrow">\n'
#  '     </div>\n'
#  '     <ol class="list-reset s-anchors s-anchors__inherit">\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-225 js-gps-track" '
#  'data-ga=\'["top navigation","teams submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:3})" '
#  'href="https://stackoverflow.co/teams/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=top-nav&amp;utm_content=stack-overflow-for-teams">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Stack Overflow for Teams\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-black-400">\n'
#  '         Where developers &amp; technologists share private knowledge with '
#  'coworkers\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-225 js-gps-track" '
#  'data-ga=\'["top navigation","advertising submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:6})" '
#  'href="https://stackoverflow.co/advertising/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=top-nav&amp;utm_content=stack-overflow-advertising">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Advertising\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-black-400">\n'
#  '         Reach devs &amp; technologists worldwide about your product, '
#  'service or employer brand\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="m6">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-225 js-gps-track" '
#  'data-ga=\'["top navigation","overflowapi submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:11})" '
#  'href="https://stackoverflow.co/api-solutions/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=top-nav&amp;utm_content=overflow-api">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Knowledge Solutions\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-black-400">\n'
#  '         Data licensing offering for businesses to build and improve AI '
#  'tools and models\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="bt bc-black-200 py6 px6 bbr-md">\n'
#  '       <a class="bar-sm p6 d-block h:bg-black-225 js-gps-track" '
#  'data-ga=\'["top navigation","labs submenu click",null,null,null]\' '
#  'data-gps-track="top_nav.products.click({location:2, destination:12})" '
#  'href="https://stackoverflow.co/labs/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=top-nav&amp;utm_content=labs">\n'
#  '        <span class="fs-body1 d-block">\n'
#  '         Labs\n'
#  '        </span>\n'
#  '        <span class="fs-caption d-block fc-black-400">\n'
#  '         The future of collective knowledge sharing\n'
#  '        </span>\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li class="bg-black-100 bt bc-black-200 py6 px6 bbr-md">\n'
#  '       <a class="fc-black-400 d-block py6 px6 h:fc-black-600" '
#  'data-ga=\'["top navigation","about submenu click",null,null,null]\' '
#  'href="https://stackoverflow.co/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=top-nav&amp;utm_content=about-the-company">\n'
#  '        About the company\n'
#  '       </a>\n'
#  '       <a class="fc-black-400 d-block py6 px6 h:fc-black-600" '
#  'data-ga=\'["top navigation","blog submenu click",null,null,null]\' '
#  'href="https://stackoverflow.blog/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=top-nav&amp;utm_content=blog">\n'
#  '        Visit the blog\n'
#  '       </a>\n'
#  '      </li>\n'
#  '     </ol>\n'
#  '    </div>\n'
#  '    <form action="/search" autocomplete="off" class="s-topbar--searchbar '
#  'js-searchbar " id="search" role="search">\n'
#  '     <div class="s-topbar--searchbar--input-group">\n'
#  '      <input aria-controls="top-search" aria-label="Search" '
#  'autocomplete="off" class="s-input s-input__search js-search-field wmn1 " '
#  'data-action="focus-&gt;s-popover#show" data-controller="s-popover" '
#  'data-s-popover-placement="bottom-start" maxlength="240" name="q" '
#  'placeholder="Search…" role="combobox" type="text" value=""/>\n'
#  '      <svg aria-hidden="true" class="s-input-icon s-input-icon__search '
#  'svg-icon iconSearch" height="18" viewbox="0 0 18 18" width="18">\n'
#  '       <path d="m18 16.5-5.14-5.18h-.35a7 7 0 1 0-1.19 1.19v.35L16.5 18zM12 '
#  '7A5 5 0 1 1 2 7a5 5 0 0 1 10 0">\n'
#  '       </path>\n'
#  '      </svg>\n'
#  '      <div class="s-popover p0 wmx100 wmn4 sm:wmn-initial '
#  'js-top-search-popover" id="top-search" role="menu">\n'
#  '       <div class="s-popover--arrow">\n'
#  '       </div>\n'
#  '       <div class="s-popover--content">\n'
#  '        <div class="js-spinner p24 d-flex ai-center jc-center d-none">\n'
#  '         <div class="s-spinner s-spinner__sm fc-orange-400">\n'
#  '          <div class="v-visible-sr">\n'
#  '           Loading…\n'
#  '          </div>\n'
#  '         </div>\n'
#  '        </div>\n'
#  '        <span class="v-visible-sr js-screen-reader-info">\n'
#  '        </span>\n'
#  '        <div class="js-ac-results overflow-y-auto hmx3 d-none">\n'
#  '        </div>\n'
#  '        <div aria-describedby="Tips for searching" class="js-search-hints">\n'
#  '        </div>\n'
#  '       </div>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </form>\n'
#  '    <nav aria-label="Topbar" class="h100 ml-auto overflow-x-auto pr12">\n'
#  '     <ol class="s-topbar--content">\n'
#  '      <li class="js-topbar-dialog-corral">\n'
#  '       <div class="topbar-dialog siteSwitcher-dialog dno" role="menu">\n'
#  '        <div class="header fw-wrap">\n'
#  '         <h3 class="flex--item">\n'
#  '          <a href="https://stackoverflow.com">\n'
#  '           current community\n'
#  '          </a>\n'
#  '         </h3>\n'
#  '         <div class="flex--item fl1">\n'
#  '          <div class="ai-center d-flex jc-end">\n'
#  '           <button aria-label="Close" class="js-close-button s-btn '
#  's-btn__muted p0 ml8 d-none sm:d-block" type="button">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconClear" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M15 4.41 13.59 3 9 7.59 4.41 3 3 4.41 7.59 9 3 13.59 '
#  '4.41 15 9 10.41 13.59 15 15 13.59 10.41 9z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '           </button>\n'
#  '          </div>\n'
#  '         </div>\n'
#  '        </div>\n'
#  '        <div class="modal-content bg-blue-200 current-site-container">\n'
#  '         <ul class="current-site">\n'
#  '          <li class="d-flex">\n'
#  '           <div class="fl1">\n'
#  '            <a class="current-site-link d-flex gx8 site-link js-gps-track" '
#  'data-gps-track="site_switcher.click({ item_type:3 })" data-id="1" '
#  'href="https://stackoverflow.com">\n'
#  '             <div class="favicon favicon-stackoverflow site-icon flex--item" '
#  'title="Stack Overflow">\n'
#  '             </div>\n'
#  '             <span class="flex--item fl1">\n'
#  '              Stack Overflow\n'
#  '             </span>\n'
#  '            </a>\n'
#  '           </div>\n'
#  '           <div class="related-links">\n'
#  '            <a class="js-gps-track" data-gps-track="site_switcher.click({ '
#  'item_type:14 })" href="https://stackoverflow.com/help">\n'
#  '             help\n'
#  '            </a>\n'
#  '            <a class="js-gps-track" data-gps-track="site_switcher.click({ '
#  'item_type:6 })" href="https://chat.stackoverflow.com/?tab=explore">\n'
#  '             chat\n'
#  '            </a>\n'
#  '           </div>\n'
#  '          </li>\n'
#  '          <li class="related-site d-flex">\n'
#  '           <div class="L-shaped-icon-container">\n'
#  '            <span class="L-shaped-icon">\n'
#  '            </span>\n'
#  '           </div>\n'
#  '           <a class="s-block-link px16 d-flex gx8 site-link js-gps-track" '
#  'data-gps-track="site.switch({ target_site:552, item_type:3 '
#  '}),site_switcher.click({ item_type:4 })" data-id="552" '
#  'href="https://meta.stackoverflow.com">\n'
#  '            <div class="favicon favicon-stackoverflowmeta site-icon '
#  'flex--item" title="Meta Stack Overflow">\n'
#  '            </div>\n'
#  '            <span class="flex--item fl1">\n'
#  '             Meta Stack Overflow\n'
#  '            </span>\n'
#  '           </a>\n'
#  '          </li>\n'
#  '         </ul>\n'
#  '        </div>\n'
#  '        <div class="header" id="your-communities-header">\n'
#  '         <h3>\n'
#  '          your communities\n'
#  '         </h3>\n'
#  '        </div>\n'
#  '        <div class="modal-content" id="your-communities-section">\n'
#  '         <div class="call-to-login">\n'
#  '          <a class="login-link js-gps-track" '
#  'data-gps-track="site_switcher.click({ item_type:10 })" '
#  'href="https://stackoverflow.com/users/signup?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-do-i-get-the-current-time-in-python">\n'
#  '           Sign up\n'
#  '          </a>\n'
#  '          or\n'
#  '          <a class="login-link js-gps-track" '
#  'data-gps-track="site_switcher.click({ item_type:11 })" '
#  'href="https://stackoverflow.com/users/login?ssrc=site_switcher&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-do-i-get-the-current-time-in-python">\n'
#  '           log in\n'
#  '          </a>\n'
#  '          to customize your list.\n'
#  '         </div>\n'
#  '        </div>\n'
#  '        <div class="header">\n'
#  '         <h3>\n'
#  '          <a href="https://stackexchange.com/sites">\n'
#  '           more stack exchange communities\n'
#  '          </a>\n'
#  '         </h3>\n'
#  '         <a class="float-right" href="https://stackoverflow.blog">\n'
#  '          company blog\n'
#  '         </a>\n'
#  '        </div>\n'
#  '        <div class="modal-content">\n'
#  '         <div class="child-content">\n'
#  '         </div>\n'
#  '        </div>\n'
#  '       </div>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <button aria-controls="search" aria-haspopup="true" '
#  'aria-label="Search" class="s-topbar--item s-btn s-btn__icon s-btn__muted '
#  'd-none sm:d-inline-flex js-searchbar-trigger" title="Click to show search">\n'
#  '        <svg aria-hidden="true" class="svg-icon iconSearch" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '         <path d="m18 16.5-5.14-5.18h-.35a7 7 0 1 0-1.19 1.19v.35L16.5 '
#  '18zM12 7A5 5 0 1 1 2 7a5 5 0 0 1 10 0">\n'
#  '         </path>\n'
#  '        </svg>\n'
#  '       </button>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="s-topbar--item s-topbar--item__unset s-btn s-btn__outlined '
#  'ws-nowrap js-gps-track" data-ga=\'["top navigation","login button '
#  'click",null,null,null]\' data-gps-track="login.click" '
#  'href="https://stackoverflow.com/users/login?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-do-i-get-the-current-time-in-python" '
#  'rel="nofollow">\n'
#  '        Log in\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="s-topbar--item s-topbar--item__unset ml4 s-btn '
#  's-btn__filled ws-nowrap js-signup-button js-gps-track" data-ga=\'["sign '
#  'up","Sign Up Navigation","Header",null,null]\' '
#  'data-gps-track="signup.topbar.click" '
#  'href="https://stackoverflow.com/users/signup?ssrc=head&amp;returnurl=https%3a%2f%2fstackoverflow.com%2fquestions%2f415511%2fhow-do-i-get-the-current-time-in-python" '
#  'rel="nofollow">\n'
#  '        Sign up\n'
#  '       </a>\n'
#  '      </li>\n'
#  '     </ol>\n'
#  '    </nav>\n'
#  '   </div>\n'
#  '  </header>\n'
#  '  <script>\n'
#  '   StackExchange.ready(function () { StackExchange.topbar.init(); });\n'
#  '\t\tStackExchange.scrollPadding.setPaddingTop(50, 10);\n'
#  '  </script>\n'
#  '  <div class="container">\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/sprinkles/left-nav-events.en.js?v=2ac13fd60bf6">\n'
#  '   </script>\n'
#  '   <div id="homepage-wizard-container">\n'
#  '   </div>\n'
#  '   <script data-module-name="islands/homepage-wizard/index.mod" '
#  'data-role="module-args" type="application/json">\n'
#  '    '
#  '{"ContainerElementId":"homepage-wizard-container","FKey":"4417dcc33c14874f9bfce957dc609794fb4ed5185ad16c86d8686c5f17054b1a","Tags":["javascript","python","java","c#","php","android","html","jquery","c++","css","ios","sql","mysql","r","reactjs","node.js","arrays","c","asp.net","json","python-3.x",".net","ruby-on-rails","sql-server","swift","django","angular","objective-c","excel","pandas","angularjs","regex","typescript","ruby","linux","ajax","iphone","vba","xml","laravel","spring","asp.net-mvc","database","wordpress","string","flutter","postgresql","mongodb","wpf","windows","amazon-web-services","xcode","bash","git","oracle-database","spring-boot","dataframe","azure","firebase","list","multithreading","docker","vb.net","react-native","eclipse","algorithm","powershell","macos","visual-studio","numpy","image","forms","scala","function","vue.js","performance","twitter-bootstrap","selenium","winforms","kotlin","loops","express","dart","hibernate","sqlite","matlab","python-2.7","shell","rest","apache","entity-framework","android-studio","csv","maven","linq","qt","dictionary","unit-testing","asp.net-core","facebook","apache-spark","tensorflow","file","swing","class","unity-game-engine","sorting","date","authentication","go","symfony","t-sql","opencv","matplotlib",".htaccess","google-chrome","for-loop","datetime","codeigniter","perl","http","validation","sockets","google-maps","object","uitableview","xaml","oop","visual-studio-code","if-statement","cordova","ubuntu","web-services","email","android-layout","github","spring-mvc","elasticsearch","kubernetes","selenium-webdriver","ms-access","ggplot2","user-interface","parsing","pointers","google-sheets","c++11","security","machine-learning","google-apps-script","ruby-on-rails-3","templates","flask","nginx","variables","exception","sql-server-2008","gradle","debugging","tkinter","listview","delphi","jpa","asynchronous","web-scraping","haskell","pdf","jsp","ssl","amazon-s3","google-cloud-platform","jenkins","testing","xamarin","wcf","batch-file","generics","npm","ionic-framework","network-programming","unix","recursion","google-app-engine","mongoose","visual-studio-2010",".net-core","android-fragments","assembly","animation","math","svg","session","intellij-idea","hadoop","rust","next.js","curl","join","winapi","django-models","laravel-5","url","heroku","http-redirect","tomcat","google-cloud-firestore","inheritance","webpack","image-processing","gcc","keras","asp.net-mvc-4","swiftui","logging","dom","matrix","pyspark","actionscript-3","button","post","optimization","firebase-realtime-database","web","jquery-ui","cocoa","xpath","iis","d3.js","javafx","firefox","xslt","internet-explorer","caching","select","asp.net-mvc-3","opengl","events","asp.net-web-api","plot","dplyr","encryption","magento","search","stored-procedures","amazon-ec2","ruby-on-rails-4","memory","canvas","audio","multidimensional-array","jsf","random","vector","redux","cookies","input","facebook-graph-api","flash","indexing","xamarin.forms","arraylist","ipad","cocoa-touch","data-structures","video","model-view-controller","azure-devops","apache-kafka","serialization","jdbc","woocommerce","razor","routes","awk","servlets","mod-rewrite","excel-formula","beautifulsoup","filter","docker-compose","iframe","aws-lambda","design-patterns","text","django-rest-framework","visual-c++","cakephp","mobile","android-intent","struct","react-hooks","methods","groovy","mvvm","ssh","lambda","checkbox","time","ecmascript-6","google-chrome-extension","grails","installation","sharepoint","cmake","shiny","spring-security","jakarta-ee","plsql","android-recyclerview","core-data","types","sed","meteor","android-activity","activerecord","bootstrap-4","websocket","graph","replace","scikit-learn","group-by","vim","file-upload","junit","boost","memory-management","sass","import","deep-learning","async-await","error-handling","eloquent","dynamic","soap","dependency-injection","silverlight","layout","apache-spark-sql","charts","deployment","browser","gr ...
#  '   </script>\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/svelte.en.js?v=b3500af90019">\n'
#  '   </script>\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/stacks-svelte.en.js?v=1c6c229c6a50">\n'
#  '   </script>\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/1130.en.js?v=8bb363934465">\n'
#  '   </script>\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/8901.en.js?v=9ff34567d3a5">\n'
#  '   </script>\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/9764.en.js?v=5b6a37bb96df">\n'
#  '   </script>\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/webpack-chunks/7194.en.js?v=e6b508b9b0d3">\n'
#  '   </script>\n'
#  '   <script defer="" '
#  'src="https://cdn.sstatic.net/Js/islands/homepage-wizard.en.js?v=a84bcf4006e6">\n'
#  '   </script>\n'
#  '   <div class="left-sidebar js-pinned-left-sidebar ps-relative" '
#  'data-is-here-when="md lg" id="left-sidebar">\n'
#  '    <div class="left-sidebar--sticky-container js-sticky-leftnav">\n'
#  '     <nav aria-label="Primary">\n'
#  '      <ol class="nav-links">\n'
#  '       <li>\n'
#  '        <ol class="nav-links">\n'
#  '         <li aria-current="false" class="ps-relative">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link pl8 '
#  'js-homepage-wizard-link js-gps-track nav-links--link -link__with-icon" '
#  'data-action="" data-controller="  " '
#  'data-gps-track="top_nav.click({is_current: false, location:2, '
#  'destination:8,  '
#  'has_activity_notification:False});home_nav.click({location:2})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" href="/">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconHome" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M15 10v5a2 2 0 0 1-2 2H5a2 2 0 0 1-2-2v-5H0l9-9 9 '
#  '9zm-8 1v6h4v-6z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             Home\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li aria-current="true" class="ps-relative youarehere">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link pl8 '
#  'js-gps-track nav-links--link -link__with-icon" data-action="" '
#  'data-controller="  " data-gps-track="top_nav.click({is_current: true, '
#  'location:2, destination:1,  has_activity_notification:False})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" href="/questions" id="nav-questions">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconQuestion" '
#  'height="18" viewbox="0 0 18 18" width="18">\n'
#  '             <path d="m4 15-3 3V4c0-1.1.9-2 2-2h12c1.09 0 2 .91 2 2v9c0 '
#  '1.09-.91 2-2 2zm7.75-3.97c.72-.83.98-1.86.98-2.94 '
#  '0-1.65-.7-3.22-2.3-3.83a4.4 4.4 0 0 0-3.02 0 3.8 3.8 0 0 0-2.32 3.83q0 1.93 '
#  '1.03 3a3.8 3.8 0 0 0 2.85 1.07q.94 0 1.71-.34.97.66 '
#  '1.06.7.34.2.7.3l.59-1.13a5 5 0 0 1-1.28-.66m-1.27-.9a5 5 0 0 '
#  '0-1.5-.8l-.45.9q.5.18.98.5-.3.1-.65.11-.92 0-1.52-.68c-.86-1-.86-3.12 '
#  '0-4.11.8-.9 2.35-.9 3.15 0 .9 1.01.86 3.03-.01 4.08">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             Questions\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li aria-current="false" class="ps-relative">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link h32 '
#  'pl8 ai-center js-disable-askstack-new-link js-gps-track nav-links--link '
#  '-link__with-icon" data-action="" data-controller="  " '
#  'data-gps-track="top_nav.click({is_current: false, location:2, '
#  'destination:33,  has_activity_notification:False})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" href="https://stackoverflow.ai" '
#  'id="nav-askstack">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <div class="d-flex ai-center mln8 mrn8 myn8 bg-purple-400 baw3 '
#  'bas-solid bc-purple-200 bar-circle fc-white p4">\n'
#  '             <svg aria-hidden="true" class="fc-white bg-transparent h16 w16 '
#  'svg-icon iconAnswerAI" height="18" viewbox="0 0 18 18" width="18">\n'
#  '              <path d="M15 1a2 2 0 0 1 2 2v14l-3-3H3c-1.09 '
#  '0-2-.91-2-2V3c0-1.09.91-2 2-2zM8.2 4.13a.2.2 0 0 0-.37 0l-.57 1.31a3.5 3.5 0 '
#  '0 1-1.82 1.82l-1.3.57a.2.2 0 0 0 0 .36l1.3.57c.82.35 1.47 1 1.82 1.82l.57 '
#  '1.3c.07.17.3.17.36 0l.57-1.3a3.5 3.5 0 0 1 1.82-1.82l1.3-.57a.2.2 0 0 0 '
#  '0-.36l-1.3-.57a3.5 3.5 0 0 1-1.82-1.82zm4.9-1.07a.1.1 0 0 0-.2 '
#  '0l-.28.66c-.17.4-.5.73-.9.9l-.66.29a.1.1 0 0 0 0 '
#  '.18l.66.29c.4.17.73.5.9.9l.29.66a.1.1 0 0 0 .18 '
#  '0l.29-.66c.17-.4.5-.73.9-.9l.66-.29a.1.1 0 0 0 '
#  '0-.18l-.66-.29c-.4-.17-.73-.5-.9-.9z">\n'
#  '              </path>\n'
#  '             </svg>\n'
#  '            </div>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             AI Assist\n'
#  '            </span>\n'
#  '            <label class="pt6 s-label s-label__sm">\n'
#  '             <span class="s-label--status s-label--status__beta">\n'
#  '              Labs\n'
#  '             </span>\n'
#  '            </label>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <script>\n'
#  '          $(\'.js-disable-askstack-new-link\').on("click", function(e) {\n'
#  '            StackExchange.helpers.toggleAccountPreferenceFlags(4194304, '
#  'true);\n'
#  '            return true;\n'
#  '        });\n'
#  '         </script>\n'
#  '         <li aria-current="false" class="ps-relative">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link pl8 '
#  'js-gps-track nav-links--link -link__with-icon" data-action="" '
#  'data-controller="  " data-gps-track="top_nav.click({is_current: false, '
#  'location:2, destination:2,  has_activity_notification:False})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" href="/tags">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconTags" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M9.24 1a3 3 0 0 0-2.12.88l-5.7 5.7a2 2 0 0 0-.38 2.31 '
#  '3 3 0 0 1 .67-1.01l6-6A3 3 0 0 1 9.83 2H14a3 3 0 0 1 .79.1A2 2 0 0 0 13 1z" '
#  'opacity=".4">\n'
#  '             </path>\n'
#  '             <path d="M9.83 3a2 2 0 0 0-1.42.59l-6 6a2 2 0 0 0 0 2.82L6.6 '
#  '16.6a2 2 0 0 0 2.82 0l6-6A2 2 0 0 0 16 9.17V5a2 2 0 0 0-2-2zM12 9a2 2 0 1 1 '
#  '0-4 2 2 0 0 1 0 4">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             Tags\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li class="pb24">\n'
#  '         </li>\n'
#  '         <li aria-current="false" class="ps-relative">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link h32 '
#  'pl8 ai-center js-disable-challenges-new-link js-gps-track nav-links--link '
#  '-link__with-icon" data-action="" data-controller="  " '
#  'data-gps-track="top_nav.click({is_current: false, location:2, '
#  'destination:32,  has_activity_notification:False})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" href="/beta/challenges" '
#  'id="nav-challenges">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconPeak" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M10.5 3.5 8 7.25l2 2.25L8.5 11l-3-3.5L1 14h16z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             Challenges\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <script>\n'
#  '          $(\'.js-disable-challenges-new-link\').on("click", function(e) {\n'
#  '            StackExchange.helpers.toggleAccountPreferenceFlags(1048576, '
#  'true);\n'
#  '            return true;\n'
#  '        });\n'
#  '         </script>\n'
#  '         <li class="ps-relative">\n'
#  '          <a aria-current="false" aria-expanded="true" class="s-block-link '
#  'pl8 ai-center js-disable-chat-new-link js-ch-popover-controller js-gps-track '
#  'nav-links--link -link__with-icon" data-controller=" " '
#  'data-gps-track="chat.click({ is_registered:false, rep_bucket:\'new\', '
#  'origin:\'Stack Overflow\' })" '
#  'href="https://chat.stackoverflow.com/rooms/259507/stack-overflow-lobby" '
#  'id="nav-chat">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <div class="d-flex ai-center mln8 mrn8 myn8 bg-purple-400 baw3 '
#  'bas-solid bc-purple-200 bar-circle fc-white p4">\n'
#  '             <svg aria-hidden="true" class="fc-white bg-transparent svg-icon '
#  'iconChatTest" height="18" viewbox="0 0 18 16" width="18">\n'
#  '              <path d="M17 3C17 1.89543 16.1046 1 15 1H7C5.89543 1 5 1.89543 '
#  '5 3V5C5 6.10457 5.89543 7 7 7H15C16.1046 7 17 6.10457 17 5V3ZM7 '
#  '3H15V5H7V3Z">\n'
#  '              </path>\n'
#  '              <path d="M17 10C17 8.89543 16.1046 8 15 8H7C5.89543 8 5 '
#  '8.89543 5 10V14C5 15.1046 5.89543 16 7 16H15C16.1046 16 17 15.1046 17 '
#  '14V10ZM7 10H15V14H7V10Z">\n'
#  '              </path>\n'
#  '              <path d="M1 9C1 8.44771 1.44772 8 2 8H3C3.55228 8 4 8.44772 4 '
#  '9V10C4 10.5523 3.55228 11 3 11H2C1.44772 11 1 10.5523 1 10V9Z">\n'
#  '              </path>\n'
#  '              <path d="M2 1C1.44772 1 1 1.44772 1 2V3C1 3.55228 1.44772 4 2 '
#  '4H3C3.55228 4 4 3.55228 4 3V2C4 1.44772 3.55228 1 3 1H2Z">\n'
#  '              </path>\n'
#  '             </svg>\n'
#  '            </div>\n'
#  '           </div>\n'
#  '           <span class="-link--channel-name pl8">\n'
#  '            Chat\n'
#  '           </span>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li aria-current="false" class="ps-relative">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link h32 '
#  'pl8 js-disable-articles-new-link js-gps-track nav-links--link '
#  '-link__with-icon" data-action="" data-controller="  " '
#  'data-gps-track="top_nav.click({is_current: false, location:2, '
#  'destination:13,  has_activity_notification:False})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" '
#  'href="https://stackoverflow.blog/contributed?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=so-blog&amp;utm_content=experiment-articles" '
#  'id="nav-articles">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconDocumentAlt" '
#  'height="18" viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M5 3a2 2 0 0 0-2 2v10c0 1.1.9 2 2 2h7a2 2 0 0 0 '
#  '2-2V5a2 2 0 0 0-2-2zm2 3a1 1 0 1 1-2 0 1 1 0 0 1 2 0m-2 '
#  '4.5c0-.28.22-.5.5-.5h6a.5.5 0 0 1 0 1h-6a.5.5 0 0 1-.5-.5m.5 1.5h6a.5.5 0 0 '
#  '1 0 1h-6a.5.5 0 0 1 0-1M5 14.5c0-.28.22-.5.5-.5h6a.5.5 0 0 1 0 1h-6a.5.5 0 0 '
#  '1-.5-.5">\n'
#  '             </path>\n'
#  '             <path d="M5.9 2h6.35A2.75 2.75 0 0 1 15 4.75v9.35c.62-.6 1-1.43 '
#  '1-2.35v-7.5C16 2.45 14.54 1 12.75 1h-4.5c-.92 0-1.75.38-2.35 1" '
#  'opacity=".4">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             Articles\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li aria-current="false" class="ps-relative">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link pl8 '
#  'js-gps-track nav-links--link -link__with-icon" data-action="" '
#  'data-controller="  " data-gps-track="top_nav.click({is_current: false, '
#  'location:2, destination:3,  has_activity_notification:False})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" href="/users" id="nav-users">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconPeople" height="18" '
#  'viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M17 14c0 .44-.45 1-1 1H9a1 1 0 0 1-1-1H2c-.54 '
#  '0-1-.56-1-1 0-2.63 3-4 3-4s.23-.4 0-1c-.84-.62-1.06-.59-1-3s1.37-3 2.5-3 '
#  '2.44.58 2.5 3-.16 2.38-1 3c-.23.59 0 1 0 1s1.55.71 2.42 2.09c.78-.72 '
#  '1.58-1.1 1.58-1.1s.23-.4 0-1c-.84-.61-1.06-.58-1-3s1.37-3 2.5-3 2.44.59 2.5 '
#  '3c.05 2.42-.16 2.39-1 3-.23.6 0 1 0 1s3 1.38 3 4">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             Users\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li class="pb24">\n'
#  '         </li>\n'
#  '         <li aria-current="false" class="ps-relative">\n'
#  '          <a aria-controls=" " aria-current="false" class="s-block-link pl8 '
#  'js-gps-track nav-links--link -link__with-icon" data-action="" '
#  'data-controller="  " data-gps-track="top_nav.click({is_current: false, '
#  'location:2, destination:12,  has_activity_notification:False})" '
#  'data-left-nav-events-navigation-activity-notification-value="" '
#  'data-left-nav-events-navigation-destination-value="" '
#  'data-left-nav-events-navigation-location-value="" '
#  'data-s-popover-auto-show="true" data-s-popover-hide-on-outside-click="never" '
#  'data-s-popover-placement="right" '
#  'href="https://stackoverflow.com/jobs/companies?so_medium=stackoverflow&amp;so_source=SiteNav" '
#  'id="nav-companies">\n'
#  '           <div class="d-flex ai-center">\n'
#  '            <svg aria-hidden="true" class="svg-icon iconIndustry" '
#  'height="18" viewbox="0 0 18 18" width="18">\n'
#  '             <path d="M10 16v-4H8v4H2V4c0-1.1.9-2 2-2h6c1.09 0 2 .91 2 '
#  '2v2h2c1.09 0 2 .91 2 2v8zM4 4v2h2V4zm0 4v2h2V8zm4-4v2h2V4zm0 4v2h2V8zm-4 '
#  '4v2h2v-2zm8 0v2h2v-2zm0-4v2h2V8z">\n'
#  '             </path>\n'
#  '            </svg>\n'
#  '            <span class="-link--channel-name pl8">\n'
#  '             Companies\n'
#  '            </span>\n'
#  '           </div>\n'
#  '          </a>\n'
#  '         </li>\n'
#  '         <li class="ml8 mt32 mb4">\n'
#  '          <div class="d-flex jc-space-between ai-center">\n'
#  '           <a aria-controls="popover-discover-collectives" class="s-link '
#  'd-flex fl-grow1 fc-black-400 h:fc-black-600 fs-fine" '
#  'data-action="s-popover#toggle" data-controller="s-popover" '
#  'data-gps-track="top_nav.click({is_current:false, location:2, '
#  'destination:17})" data-s-popover-placement="top" '
#  'data-s-popover-toggle-class="is-selected" href="javascript:void(0)" '
#  'role="button">\n'
#  '            <div class="flex--item fl-grow1 tt-uppercase fc-black-600 '
#  'fw-bold">\n'
#  '             Collectives\n'
#  '            </div>\n'
#  '            <div class="flex--item px12 js-collectives-navcta-toggle">\n'
#  '             <svg aria-hidden="true" class="svg-icon iconPlusSm" height="14" '
#  'viewbox="0 0 14 14" width="14">\n'
#  '              <path d="M8 2H6v4H2v2h4v4h2V8h4V6H8z">\n'
#  '              </path>\n'
#  '             </svg>\n'
#  '            </div>\n'
#  '           </a>\n'
#  '          </div>\n'
#  '         </li>\n'
#  '         <li class="ps-relative js-collectives-navcta-toggle">\n'
#  '          <p class="fs-fine pr8 pl8 pt4 fc-black-400">\n'
#  '           Communities for your favorite technologies.\n'
#  '           <a class="s-link s-link__grayscale s-link__underlined fw-bold" '
#  'href="/collectives-all">\n'
#  '            Explore all Collectives\n'
#  '           </a>\n'
#  '          </p>\n'
#  '         </li>\n'
#  '        </ol>\n'
#  '       </li>\n'
#  '       <li class="js-freemium-cta ps-relative mt32 mb8">\n'
#  '        <div class="fs-fine tt-uppercase fc-black-600 fw-bold ml8 mt16 '
#  'mb8">\n'
#  '         Teams\n'
#  '        </div>\n'
#  '        <div class="px12 pt12 pb4 mb12 fc-medium overflow-hidden">\n'
#  '         <img alt="" class="wmx100 mx-auto mb12 h-auto d-block" height="24" '
#  'src="https://cdn.sstatic.net/Img/teams/teams-promo.svg?v=e507948b81bf" '
#  'width="151"/>\n'
#  '         <p class="fs-fine">\n'
#  '          Ask questions, find answers and collaborate at work with Stack '
#  'Overflow for Teams.\n'
#  '         </p>\n'
#  '         <a class="w100 s-btn s-btn__filled s-btn__xs bg-orange-400 '
#  'h:bg-orange-500 js-gps-track pt8 pr7 pb6 pl7" data-ga=\'["teams left '
#  'navigation - anonymous","left nav free '
#  'cta","stackoverflow.com/teams/create/free",null,null]\' '
#  'data-gps-track="teams.create.left-sidenav.click({ Action: 6 })" '
#  'href="https://stackoverflowteams.com/teams/create/free/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=side-bar&amp;utm_content=explore-teams">\n'
#  '          Try Teams for free\n'
#  '         </a>\n'
# ...
#  '        <button class="s-btn s-btn__link py4 js-gps-track -link" '
#  'data-action="click-&gt;cookie-settings#toggle" '
#  'data-consent-popup-loader="footer" data-controller="cookie-settings" '
#  'data-gps-track="footer.click({ location: 2, link: 38 })" type="button">\n'
#  '         Cookie Settings\n'
#  '        </button>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 39 })" '
#  'href="https://policies.stackoverflow.co/stack-overflow/cookie-policy">\n'
#  '         Cookie Policy\n'
#  '        </a>\n'
#  '       </li>\n'
#  '      </ul>\n'
#  '     </div>\n'
#  '     <div class="site-footer--col site-footer--categories-nav">\n'
#  '      <div>\n'
#  '       <h5 class="-title">\n'
#  '        <a data-gps-track="footer.click({ location: 2, link: 30 })" '
#  'href="https://stackexchange.com">\n'
#  '         Stack Exchange Network\n'
#  '        </a>\n'
#  '       </h5>\n'
#  '       <ul class="-list">\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" '
#  'href="https://stackexchange.com/sites#technology">\n'
#  '          Technology\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" '
#  'href="https://stackexchange.com/sites#culturerecreation">\n'
#  '          Culture &amp; recreation\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://stackexchange.com/sites#lifearts">\n'
#  '          Life &amp; arts\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://stackexchange.com/sites#science">\n'
#  '          Science\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" '
#  'href="https://stackexchange.com/sites#professional">\n'
#  '          Professional\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://stackexchange.com/sites#business">\n'
#  '          Business\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="mt16 md:mt0">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://api.stackexchange.com/">\n'
#  '          API\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://data.stackexchange.com/">\n'
#  '          Data\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </nav>\n'
#  '    <div class="site-footer--copyright fs-fine md:mt24">\n'
#  '     <ul class="-list -social md:mb8">\n'
#  '      <li>\n'
#  '       <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link:4 })" href="https://stackoverflow.blog?blb=1">\n'
#  '        Blog\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 31 })" '
#  'href="https://www.facebook.com/officialstackoverflow/">\n'
#  '        Facebook\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 32 })" href="https://twitter.com/stackoverflow">\n'
#  '        Twitter\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 33 })" '
#  'href="https://linkedin.com/company/stack-overflow">\n'
#  '        LinkedIn\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n''      </svg>\n'
#  '     </a>\n'
#  '    </div>\n'
#  '    <nav aria-label="Footer" class="site-footer--nav">\n'
#  '     <div class="site-footer--col">\n'
#  '      <h5 class="-title">\n'
#  '       <a class="js-gps-track" data-gps-track="footer.click({ location: 2, '
#  'link: 15})" href="https://stackoverflow.com">\n'
#  '        Stack Overflow\n'
#  '       </a>\n'
#  '      </h5>\n'
#  '      <ul class="-list js-primary-footer-links">\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 16})" href="/questions">\n'
#  '         Questions\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 3 })" href="/help">\n'
#  '         Help\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 5 })" '
#  'href="https://chat.stackoverflow.com/?tab=explore">\n'
#  '         Chat\n'
#  '        </a>\n'
#  '       </li>\n'
#  '      </ul>\n'
#  '     </div>\n'
#  '     <div class="site-footer--col">\n'
#  '      <h5 class="-title">\n'
#  '       <a class="js-gps-track" data-gps-track="footer.click({ location: 2, '
#  'link: 19 })" href="https://stackoverflow.co/">\n'
#  '        Products\n'
#  '       </a>\n'
#  '      </h5>\n'
#  '      <ul class="-list">\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-ga=\'["teams traffic","footer - '
#  'site nav","stackoverflow.com/teams",null,{"dimension4":"teams"}]\' '
#  'data-gps-track="footer.click({ location: 2, link: 29 })" '
#  'href="https://stackoverflow.co/teams/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=footer&amp;utm_content=teams">\n'
#  '         Teams\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 21 })" '
#  'href="https://stackoverflow.co/advertising/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=footer&amp;utm_content=advertising">\n'
#  '         Advertising\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 20 })" '
#  'href="https://stackoverflow.co/advertising/employer-branding/?utm_medium=referral&amp;utm_source=stackoverflow-community&amp;utm_campaign=footer&amp;utm_content=talent">\n'
#  '         Talent\n'
#  '        </a>\n'
#  '       </li>\n'
#  '      </ul>\n'
#  '     </div>\n'
#  '     <div class="site-footer--col">\n'
#  '      <h5 class="-title">\n'
#  '       <a class="js-gps-track" data-gps-track="footer.click({ location: 2, '
#  'link: 1 })" href="https://stackoverflow.co/">\n'
#  '        Company\n'
#  '       </a>\n'
#  '      </h5>\n'
#  '      <ul class="-list">\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 1 })" href="https://stackoverflow.co/">\n'
#  '         About\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 27 })" href="https://stackoverflow.co/company/press/">\n'
#  '         Press\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 9 })" '
#  'href="https://stackoverflow.co/company/work-here/">\n'
#  '         Work Here\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 7 })" href="https://stackoverflow.com/legal">\n'
#  '         Legal\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 8 })" '
#  'href="https://stackoverflow.com/legal/privacy-policy">\n'
#  '         Privacy Policy\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 37 })" '
#  'href="https://stackoverflow.com/legal/terms-of-service/public">\n'
#  '         Terms of Service\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 13 })" href="/contact">\n'
#  '         Contact Us\n'
#  '        </a>\n'
#  '       </li>\n'
#  '       <li id="consent-footer-link">\n'
#  '        <button class="s-btn s-btn__link py4 js-gps-track -link" '
#  'data-action="click-&gt;cookie-settings#toggle" '
#  'data-consent-popup-loader="footer" data-controller="cookie-settings" '
#  'data-gps-track="footer.click({ location: 2, link: 38 })" type="button">\n'
#  '         Cookie Settings\n'
#  '        </button>\n'
#  '       </li>\n'
#  '       <li>\n'
#  '        <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link: 39 })" '
#  'href="https://policies.stackoverflow.co/stack-overflow/cookie-policy">\n'
#  '         Cookie Policy\n'
#  '        </a>\n'
#  '       </li>\n'
#  '      </ul>\n'
#  '     </div>\n'
#  '     <div class="site-footer--col site-footer--categories-nav">\n'
#  '      <div>\n'
#  '       <h5 class="-title">\n'
#  '        <a data-gps-track="footer.click({ location: 2, link: 30 })" '
#  'href="https://stackexchange.com">\n'
#  '         Stack Exchange Network\n'
#  '        </a>\n'
#  '       </h5>\n'
#  '       <ul class="-list">\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" '
#  'href="https://stackexchange.com/sites#technology">\n'
#  '          Technology\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" '
#  'href="https://stackexchange.com/sites#culturerecreation">\n'
#  '          Culture &amp; recreation\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://stackexchange.com/sites#lifearts">\n'
#  '          Life &amp; arts\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://stackexchange.com/sites#science">\n'
#  '          Science\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" '
#  'href="https://stackexchange.com/sites#professional">\n'
#  '          Professional\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://stackexchange.com/sites#business">\n'
#  '          Business\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li class="mt16 md:mt0">\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://api.stackexchange.com/">\n'
#  '          API\n'
#  '         </a>\n'
#  '        </li>\n'
#  '        <li>\n'
#  '         <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 24 })" href="https://data.stackexchange.com/">\n'
#  '          Data\n'
#  '         </a>\n'
#  '        </li>\n'
#  '       </ul>\n'
#  '      </div>\n'
#  '     </div>\n'
#  '    </nav>\n'
#  '    <div class="site-footer--copyright fs-fine md:mt24">\n'
#  '     <ul class="-list -social md:mb8">\n'
#  '      <li>\n'
#  '       <a class="js-gps-track -link" data-gps-track="footer.click({ '
#  'location: 2, link:4 })" href="https://stackoverflow.blog?blb=1">\n'
#  '        Blog\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 31 })" '
#  'href="https://www.facebook.com/officialstackoverflow/">\n'
#  '        Facebook\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 32 })" href="https://twitter.com/stackoverflow">\n'
#  '        Twitter\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 33 })" '
#  'href="https://linkedin.com/company/stack-overflow">\n'
#  '        LinkedIn\n'
#  '       </a>\n'
#  '      </li>\n'
#  '      <li>\n'
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 36 })" '
#  'href="https://www.instagram.com/thestackoverflow">\n'
#  '        Instagram\n'
#  '       </a>\n'
#  '      </li>\n'
#  '     </ul>\n'
#  '     <p class="md:mb0">\n'
#  '      <span>\n'
#  '       Site design / logo © 2025 Stack Exchange Inc;\n'
#  '      </span>\n'
#  '      <span>\n'
#  '       user contributions licensed under\n'
#  '      </span>\n'
#  '      <a class="-link s-link td-underline" '
#  'href="https://stackoverflow.com/help/licensing">\n'
#  '       CC BY-SA\n'
#  '      </a>\n'
#  '      <span>\n'
#  '       .\n'
#  '      </span>\n'
#  '      <span id="svnrev">\n'
#  '       rev\xa02025.9.4.33555\n'
#  '      </span>\n'
#  '     </p>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '  </footer>\n'
#  '  <script>\n'
#  '   (function(){function c(){var '
#  'b=a.contentDocument||a.contentWindow.document;if(b){var '
#  'd=b.createElement(\'script\');d.innerHTML="window.__CF$cv$params={r:\'97c3b4f5a9659fa3\',t:\'MTc1NzM4OTY3NC4wMDAwMDA=\'};var '
#  'a=document.createElement(\'script\');a.nonce=\'\';a.src=\'/cdn-cgi/challenge-platform/scripts/jsd/main.js\';document.getElementsByTagName(\'head\')[0].appendChild(a);";b.getElementsByTagName(\'head\')[0].appendChild(d)}}if(document.body){var '
#  "a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else "
#  "if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var "
#  "e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();\n"
#  '  </script>\n'
#  ' </body>\n'
#  '</html>\n')
#
#  '       <a class="-link js-gps-track" data-gps-track="footer.click({ '
#  'location: 2, link: 36 })" '
#  'href="https://www.instagram.com/thestackoverflow">\n'
#  '        Instagram\n'
#  '       </a>\n'
#  '      </li>\n'
#  '     </ul>\n'
#  '     <p class="md:mb0">\n'
#  '      <span>\n'
#  '       Site design / logo © 2025 Stack Exchange Inc;\n'
#  '      </span>\n'
#  '      <span>\n'
#  '       user contributions licensed under\n'
#  '      </span>\n'
#  '      <a class="-link s-link td-underline" '
#  'href="https://stackoverflow.com/help/licensing">\n'
#  '       CC BY-SA\n'
#  '      </a>\n'
#  '      <span>\n'
#  '       .\n'
#  '      </span>\n'
#  '      <span id="svnrev">\n'
#  '       rev\xa02025.9.4.33555\n'
#  '      </span>\n'
#  '     </p>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '  </footer>\n'
#  '  <script>\n'
#  '   (function(){function c(){var '
#  'b=a.contentDocument||a.contentWindow.document;if(b){var '
#  'd=b.createElement(\'script\');d.innerHTML="window.__CF$cv$params={r:\'97c3b4f5a9659fa3\',t:\'MTc1NzM4OTY3NC4wMDAwMDA=\'};var '
#  'a=document.createElement(\'script\');a.nonce=\'\';a.src=\'/cdn-cgi/challenge-platform/scripts/jsd/main.js\';document.getElementsByTagName(\'head\')[0].appendChild(a);";b.getElementsByTagName(\'head\')[0].appendChild(d)}}if(document.body){var '
#  "a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else "
#  "if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var "
#  "e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();\n"
#  '  </script>\n'
#  ' </body>\n'
#  '</html>\n')

# %%
pprint(soupified.prettify()[:2000]) # to get an idea of the html structure of the webpage
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="html__responsive " itemscope="" '
#  'itemtype="https://schema.org/QAPage" lang="en">\n'
#  ' <head>\n'
#  '  <title>\n'
#  '   datetime - How do I get the current time in Python? - Stack Overflow\n'
#  '  </title>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" '
#  'rel="shortcut icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="apple-touch-icon"/>\n'
#  '  <link '
#  'href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" '
#  'rel="image_src"/>\n'
#  '  <link href="/opensearch.xml" rel="search" title="Stack Overflow" '
#  'type="application/opensearchdescription+xml"/>\n'
#  '  <link '
#  'href="https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python" '
#  'rel="canonical">\n'
#  '   <meta content="width=device-width, height=device-height, '
#  'initial-scale=1.0, minimum-scale=1.0" name="viewport"/>\n'
#  '   <meta content="website" property="og:type">\n'
#  '    <meta '
#  'content="https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python" '
#  'property="og:url"/>\n'
#  '    <meta content="Stack Overflow" property="og:site_name"/>\n'
#  '    <meta '
#  'content="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded" '
#  'itemprop="image primaryImageOfPage" property="og:image"/>\n'
#  '    <script type="application/ld+json">\n'
#  '     {\n'
#  '              "@context" : "https://schema.org",\n'
#  '              "@type" : "WebSite",\n'
#  '              "name" : "Stack Overflow",\n'
#  '              "url" : "https://stackoverflow.com"\n'
#  '            }\n'
#  '    </script>\n'
#  '    <meta content="summary" name="twitter:card"/>\n'
#  '    <meta content="stackoverflow.com" name="twitter:domain"/>\n'
#  '    <meta content="How do I get the current time in Python?" itemprop="name" '
#  'name="twitter:title" property="og:title"/>\n'
#  '    <meta content="How do I get the current time in Python?" '
#  'itemprop="description" name="twitter:description" '
#  'property="og:description"/>\n'
#  '    <script id="webpack-public-path" type="text/uri-list">\n'
#  '     https://cdn.')

# %%
soupified.title # to get the title of the web page
# Out:
# <title>datetime - How do I get the current time in Python? - Stack Overflow</title>

# %%
question = soupified.find("div", {"class": "question"}) # find the nevessary tag and class which it belongs to
questiontext = question.find("div", {"class": "s-prose js-post-body"})
print("Question: \n", questiontext.get_text().strip())

answer = soupified.find("div", {"class": "answer"}) # find the nevessary tag and class which it belongs to
answertext = answer.find("div", {"class": "s-prose js-post-body"})
print("Best answer: \n", answertext.get_text().strip())
# Out:
# Question:
#  How do I get the current time in Python?
# Best answer:
#  Use datetime:
# >>> import datetime
# >>> now = datetime.datetime.now()
# >>> now
# datetime.datetime(2009, 1, 6, 15, 8, 24, 78915)
# >>> print(now)
# 2009-01-06 15:08:24.789150
#
# For just the clock time without the date:
# >>> now.time()
# datetime.time(15, 8, 24, 78915)
# >>> print(now.time())
# 15:08:24.789150
#
#
# To save typing, you can import the datetime object from the datetime module:
# >>> from datetime import datetime
#
# Then remove the prefix datetime. from all of the above.

# %% [markdown]
# BeautifulSoup is one of the many libraries which allow us to scrape web pages. Depending on your needs you can choose between the many available choices like beautifulsoup, scrapy, selenium, etc
